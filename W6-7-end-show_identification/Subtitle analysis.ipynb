# %% [markdown]
# ## Subtitle analysis

# %%
import os
import pysrt
import re
import time as tm
from collections import Counter

# %%
def sec2HMS(seconds):
    #seconds = int(seconds)
    return tm.strftime('%H:%M:%S', tm.gmtime(seconds))

def HMS2sec(time_str):
    h, m, s = time_str.split(':')
    return int(h) * 3600 + int(m) * 60 + int(s)

# %%
from html.parser import HTMLParser

class MLStripper(HTMLParser):
    def __init__(self):
        self.reset()
        self.strict = False
        self.convert_charrefs= True
        self.fed = []
    def handle_data(self, d):
        self.fed.append(d)
    def get_data(self):
        return ''.join(self.fed)

def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()

# %%
subs = pysrt.open('../data/2006-01-02_0000_US_00001057_V11_M2_VHS10_H4_JA.srt')

# %%
full_srt = ' '.join([x.text for x in subs])
full_srt = re.sub('!|;|:|\.|,|\?','',full_srt)
full_srt = strip_tags(full_srt)

# %% [markdown]
# #### All subtitles near the boundaries

# %%
boundaries = [38,7241,10842,21593]

# %%
for sub in subs:
    time = list(sub.start)
    time = time[2] + 60*time[1] + 3600*time[0]
    for start in boundaries:
        if abs(start-time)<=300:
            print(sub.text)
            print(time)
            print()
# Out:
#     --<font color="#ffff00"> Captions by VITAC</font> --
#         <font color="#00ffff"> www.vitac.com</font>
# 37
#
# >>> A GREAT 2006 TO YOU IN
# NO, CITY.
# 42
#
# WE'LL GO AHEAD AND START THE
# YEAR, FIRST MONDAY AND, BOY, IS
# 46
#
# WEATHER E WORD TODAY FOR MU
# OF TH U.S.
# 50
#
# THE O MOST DESTRUCTIVE FORMS
# OF WEATHER ARE OUT THERE IN
# 52
#
# POLAR OPPOSITES.
# WE HAVE FIRE AND RAIN.
# 56
#
# FIRES SCORCHING THE SOUTHWEST
# AND ENTI TOWNS HAVE BEEN WIPED
# 59
#
# OUT.
# WE HAVE LIVE TEAM COVERAGE AND
# 62
#
# RAIN WH IT, FOODING AND MUD
# SLIDES DRENCHING CALORNIA.
# 64
#
# THE NORTHERN PART OF THE STATE
# HEADED FOR MUCH OF THE WEEKEND
# 68
#
# AND NOW SOUTHERN CALIFORNIA IS
# GETTING SOAKED.
# 70
#
# VEEACOVERAGE OF THE SOGGY
# CONDITIONS AS WELL AHEAD ON CNN
# 73
#
# "LIVE TODAY," FIRST A QUICK
# CHECK OF OTHER STORIES HAPPENING
# 77
#
# NOW IN THE NEWS.
# >>> U.N. INVESTIGATORS SAY THEY
# 80
#
# WANT TO INTERVIEW A SERIOUS
# PRESIDENT IN LAST YEAR'S
# 83
#
# ASSSINATION OF FORMER
# LEBANESE LEADER.
# 86
#
# THEY QUOTE THE VICE PRESIDENT A
# SAYING ASSAD MADE DIRECT
# 89
#
# PERSONAL THREATS AGAINST RAFIK
# HARIRI MONTHS BEFORE HIS
# 94
#
# FEBRUARY ASSASSINATION.
# INVESTIGATORS WANT TO QUESTION
# 99
#
# SYRIA'S FOREIGN MINISTER.
# >>> HE'S TURNED IN HIS
# 104
#
# RESIGNATION.
#  SAYS THAT THE PRICE INCREASE
# 109
#
# WILL NEGATIVELY IMPACT THE
# LIVING CONDITIONS OF MANY IRAQIS
# 111
#
# WHO ARE ALREADY STRUGGLING TO
# SURVIVE.
# 114
#
# >>> HERE IN THE U.S., A FLORIDA
# TEENAGER IS BACK HOME FROM IRAQ
# 117
#
# AFTER RUNNING AWAY FROM A
# HAIR-RAISING, GLOBE-TROTTING
# 121
#
# ADVENTURE.
# 16-YEAR-OLD FARRIS HASSAN WAS
# 125
#
# GREETED LAST NIGHT BY HIS
# PARENTS WHO WHISKED HIM AWAY
# 128
#
# FROM THE MEDIA THAT FOLLOWED HIS
# JOURNEY
# 131
#
# LATER THIS HOUR WE WILL HEAR
# FROM HIS MOTHER.
# 134
#
# >>> HELLO AND GOOD MORNING AND
# HAPPY NEW YEAR TO YOU.
# 142
#
# I'M DARYN KAGAN AT CNN CENTER IN
# ATLANTA.
# 145
#
# WE START IN CALIFORNIA WHERE
# RESIDENTS INHE SOUTH ARE
# 148
#
# BRACING FOR THE LATEST STORM.
# WHILE NEIGHBORS TO THE NORTH
# 150
#
# BEGIN A MASSIVE CLEANUP, THE
# STORM UNLEASHED MUD SLIDES AND
# 154
#
# THREATENED LEVEES AND ROAD
# CLOSURES.
# 160
#
# LIVE REPORTS FOR YOU THIS HOUR
# FROM TWO HARDEN HARD HIT AREAS
# 164
#
# IN THE NORTH.
# WE'LL BEGIN FARTHER SOUTH IN
# 168
#
# SANTA MONICA.
# NOTOO FAR AWAY WHERE THEY'RE
# 171
#
# AWAITING TO BEGINNING OF THE
# ROSE PARADE.
# 174
#
# JEN RODGERS IS THERE.
# HI, JEN.
# 176
#
# >> HI THERE, DARYN.
# SO FAR WE HAVE NOT HAD AS MUCH
# 178
#
# RAIN AS WE EXPECTED.
# IT HASN'T LIVED UP TO
# 181
#
# EXPECTATIONS, BUT WHAT WE HAVE
# HAD A LOT OF IS REALLY HIGH
# 184
#
# WIND.
# WE'RE EXPECTING GUSTS UP TO 40
# 187
#
# MILES PER HOUR.
# I'LL SHOW YOU WHAT THE TREES ARE
# 189
#
# DOING HERE.
# WE'RE LOSING BRANCHES.
# 191
#
# THE TREES HAVE BEEN BLONG
# PRETTY STEAILY A MORNING
# 193
#
# LONG.
# ONE OF THE BIG ISSUES HERE IS
# 196
#
# GOING TO BE THAT WE'VE HAD SO
# MUCH RAIN OVER THE LAST COUPLE
# 198
#
# OF WEEKS AND OVER THIS WEEKEND
# ESPECIALLY THAT THE GROUND IS
# 201
#
# ALREADY VERY SOFT.
# SO MUDSLIDES AND LANDSLIDES WILL
# 204
#
# BE AN ISSUE.
# RIGHT NOW WE'RE ABOVE PACIFIC
# 207
#
# COAST HIGHWAY.
# THIS LEADS UP TO MALIBU AND YOU
# 210
#
# CAN SEE IT'S A VERY STEEP CLIFF.
# IF WE GET A LOT OF RAIN THIS
# 213
#
# WOULD BE A PLACE THAT YOU COULD
# BE LOOKING FOR MUDSLIDES AND
# 216
#
# LANDSLIDES AND PLACES LIKE THIS
# ARE COMMON ALL UP AND DOWN THE
# 220
#
# COAST.
# TAKE A LOOK OUT TO THE BEACH.
# 223
#
# WE ALSO HAVE A HIGH SURF WARNING
# IN EFFECT.
# 225
#
# YOU CAN SEE THE BIG WHITE WAVES
# OUT THERE POUNDING THE COAST.
# 227
#
# A HIGH SURF ADVISORY, A HIGH
# WIND ADVISORY AND WE DO HAVE A
# 231
#
# FLASH FLOOD WATCH IN EFFECT FOR
# THE BURN AREAS AND THOSE ARE
# 235
#
# OUTSIDE OF A LOS ANGELES CITY
# PROPER, BUT BURN AREAS WILL BE
# 238
#
# WHERE THEY'VE HAD FOREST FIRES
# OR FIRES DURING THE SUMMER AND
# 241
#
# FALL SO PEOPLE WILL BE WATCHING
# FOR SOME ISSUES THERE AS WELL.
# 244
#
# SO FAR, DARYN, THE RAIN KEEPING
# OFF A LITTLE BIT, BUT I'M NOT
# 247
#
# SURE THEY'LL GET A BAY WITH THE
# ROSE BOWL PARADE NOT GETTING A
# 251
#
# DROP ON IT, BUT WE'LL SEE.
# I'M FLASHING BACK BECAUSE THOSE
# 255
#
# VERY BEACHES ARE WHERE I LIVED
# OUT MY TEENAGE YEARS SO I KNOW
# 258
#
# THAT PART OF PCH AND THE PART
# THAT USUALLY HAS MUDSLIDES IS
# 262
#
# FARTHER UP AND CLOSER TO MALIBU
# IS THE WORD THAT THINGS ARE
# 266
#
# STILL LOOKING GOOD OUT IN THAT
# DIRECTION.
# 269
#
# >> YOU KNOW, RIGHT NOW WE DON'T
# HAVE REPORTS ANY OF MAJOR SLIDES
# 271
#
# IN THAT AREA, BUT, OF COURSE,
# THAT WOULD BE AN AREA AND EVEN
# 274
#
# THOUGH THIS IS A PUBLIC HOLIDAY,
# WE'RALREADY STARTING TO SEE
# 277
#
# TRAFFIC PICK UP A BIT AND WE
# HAVE ALREADY SEEN ONE ACCIDENT.
# 281
#
# I TALKED TO THE HIGHWAY PATROL.
# THEY'VE SEEN ALMOST DOUBLE THE
# 284
#
# NUMBER OF ACCIDENTS THEY WOULD
# ON A NORMAL MORNING.
# 287
#
# SO TRAFFIC WILL BE AN ISSUE.
# WE'LL BE WATCHING ALL THESE
# 289
#
# ROADS FOR SURE.
# >> JEN RODGERS IN SANTA MONICA,
# 292
#
# CALIFORNIA, THANK YOU.
# ABOUT AN HOUR AWAY FROM WHERE
# 296
#
# JEN'S STANDING IN PASADENA
# THEY'RSTANDING BY FOR THE ROSE
# 298
#
# PARADE TO BEGIN.
# THE ROSE PARADE TAKES PLACE ON
# 303
#
# NEW YEAR'S DAY AND NEVER ON A
# SUNDAY.
# 306
#
# SO THEY DELAYED IT UNTIL TODAY.
# NOAIN H FALL OWN THIS PARADE
# 308
#
# IN OVER 50 YEARS AND IT LOOK
# LIKE THEY MIGHT GET AING SO ONE
# 311
#
# TODAY AND STILL THE PARADE IS
# SET TO GO ON.
# 315
#
# >> LET'S MOVE TO NORTHERN
# CALIFORNIA.
# 317
#
# A QUAINT TOWN OF SAN ANSELMO IN
# MARIN COUNTY HAS BEEN
# 320
#
# TRANSFORMED BY THE TYPE OF
# FLOONG HAS NOT SEEN THERE IN
# 324
#
# DECADES.
# CNN'S KATHERINE BARRETT JOINS US
# 327
#
# IN SAN ANSELMO, THE DAMAGE
# ESTIMATED IN THE TENSE OF
# 331
#
# MILLIONS OF DOLLARS.
# GOOD MORNING.
# 334
#
# >> GOOD MORNING TO YOU, DARYN.
# THAT'S RIGHT.
# 336
#
# 13 STILL TRAPPED A MILD
# UNDERGROUND.
# 6945
#
# SO FAR THEY HAVE NOT BEEN ABLE
# TO ESTABLISH ANY COMMUNICATION.
# 6947
#
# >>> FOR THE GENERATION WHO MADE
# YOUTH THE CENTER OF AMERICAN
# 6951
#
# CULTURE, THE '60s TOOK ON A
# WHOLE NEW MEANING.
# 6954
#
# THE FIRST OFFICIAL BABY BOOMER
# TURNED 60 YESTERDAY.
# 6958
#
# LATER WHEN MONEY MAGAZINE WENT
# LOOK FOR BOOMERS TURNING 40.
# 6966
#
# NOW SHE FINDS HERSELF ONCE AGAIN
# THE POSTER CHILD FOR HER
# 6970
#
# GENERATION.
# >> I THINK THAT ONE OF THE
# 6974
#
# THINGS THAT DEFINES IT IS MOST
# PROBABLY DIVERSITY AND CHANGE
# 6977
#
# AND GROWTH.
# BECAUSE I THINK WE EMBRACE
# 6982
#
# DIVERSITY OVER THE LAST 40
# YEARS.
# 6986
#
# AND I THINK THAT'S A REAL GREAT
# LEGACY.
# 6988
#
# I THINK THERE WAS LOTS OF
# CHANGES AND WE BROUGHT A LOT OF
# 6991
#
# GOOD BUT WE ALSO MOST PROBABLY
# BROUGHT A LOT OF NEGATIVE.
# 6995
#
# THAT IS CHANGING RIGHT NOW.
# >> TRUE TO HER GENERATION SHE IS
# 6999
#
# NOT ALONE.
# ALMOST 8,000 BOOMERS WILL TURN
# 7002
#
# 60 EACH DAY THIS YEAR.
# >> I'M DARYN KAGAN.
# 7005
#
# INTERNATIONAL NEWS SUP NEXT.
# STAY TUNE POD THE WORLD NEWS
# 7009
#
# TODAY.
# JIM CLANCY AND ZAIN VERJEE WILL
# 7015
#
# BE WITH YOU AFTER A QUICK BREAK.
# 7018
#
# >>> COMPLAINTS MT. IN EUROPE AS
# THE GAS WAR WITH KIEV BRINGS
# 7220
#
# ACCUSATIONS OF THEFT AND
# BLACKMAIL.
# 7225
#
# >> THE U.N. LOOKS TO SYRIA'S
# PRESIDENT AS IT INVESTIGATES THE
# 7227
#
# FORMER LEBANESE PRIME MINISTER
# RAFIK HARIRI.
# 7233
#
# >>> IT'S NOON IN WASHINGTON,
# 8:00 PM IN MOSCOW.
# 7240
#
# I'M ROSALEE CHURCH.
# >> THIS IS YOUR "YOUR WORLD
# 7244
#
# TODAY."
# 7252
#
# >>> WOMEN COME OUR VIEWERS IN
# THE UNITED STATES AND AROUND THE
# 7261
#
# WORLD.
# WE'LL HAVE MORE ON THOSE STORIES
# 7264
#
# IN JUST A MOMENT.
# WE WANT TO KEEP YOU UPDATED IN
# 7266
#
# SOUTHERN GERMANY WHERE A ROOF
# HAS COLLAPSED AT AN ICE SKATING
# 7269
#
# RINK.
# HEAVY SNOW FALL IS BEING BLAMED
# 7272
#
# FOR THAT.
# POLICE SAY AT LEAST ONE PERSON
# 7274
#
# HAS BEEN KILLED.
# BUT DOZENS MORE ARE STILL
# 7276
#
# UNACCOUNTED FOR.
# CHRIS BURNS JOINS US ON THE LINE
# 7279
#
# FROM BERLIN.
# HOW MUCH DO WE KNOW AT THIS
# 7282
#
# POINT FROM THE RESCUE WORKER
# SNS.
# 7285
#
# >> Reporter: JIM, THIS IS A
# WRENCHING SITUATION RIGHT NOW.
# 7287
#
# THOSE RESCUE WORKERS ARE WAITING
# AND HOPING THAT A HEAVY CRANE
# 7289
#
# ARRIVE IN THE HEAVY SNOW, WHICH
# IS HOLDING THAT CRANE UP, BACK
# 7294
#
# FROM ARRIVING FROM THIS LITTLE
# TOWN.
# 7298
#
# THIS IS WHERE THIS ROOF
# COLLAPSED SOMETIME THIS
# 7301
#
# AFTERNOON OVER AN ICE SKATING
# RINK, PARTIAL COLLAPSED UNDER
# 7306
#
# HEAVY SNOW.
# THEY BELIEVE SOME 50 PEOPLE WERE
# 7310
#
# INSIDE.
# SO FAR, 10 PEOPLE ALIVE HAVE
# 7313
#
# BEEN PULLED OUT OF THAT,
# SLIGHTLY INJURED.
# 7315
#
# ONE SERIOUSLY INJURED, WHO THEY
# HAD TO REVIVE, AND ONE PERSON,
# 7318
#
# AT LEAST ONE PERSON DEAD.
# THERE COULD BE DOZENS TRAPPED
# 7322
#
# UNDER THERE, JIM.
# >> NOW, AS WE UNDERSTAND IT,
# 7325
#
# THEY HAVE HAD THESE KINDS OF
# SITUATIONS BEFORE IN GERMANY
# 7328
#
# FAIRLY PREPARED FOR IT.
# AND YET THERE'S GOT TO BE A LOT
# 7333
#
# OF PEOPLE TODAY ASKING HOW COULD
# IT HAVE HAPPENED, PEOPLE WERE
# 7336
#
# INSIDE THERE?
# >> Reporter: IT'S HARD TO TELL.
# 7341
#
# I TRY TODAY PIN DOWN POLICE ON
# WHAT THE CAUSE WAS.
# 7346
#
# THEY WOULD NOT SAY RIGHT AWAY
# THAT IT WAS THE SNOW THAT CAUSED
# 7349
#
# THIS.
# THERE HAVE BEEN DAYS AND DAYS OF
# 7351
#
# VERY HEAVY SNOW ACROSS EUROPE
# AND ESPECIALLY IN GERMANY AND
# 7353
#
# THE OTHER ALPINE REGIONS.
# THIS IS WHAT HAS HAPPENED.
# 7358
#
# IT'S MIXED WITH HEAVY RAIN AS
# WELL.
# 7362
#
# RAIN AND SNOW MIXING WITH ICE,
# MAKING IT AN ACCIDENT WAITING TO
# 7364
#
# HAPPEN, JIM.
# >> THIS IS ALL HAPPENING RIGHT
# 7368
#
# NOW IN THE VERY SOUTHERN PART OF
# GERMAN
# 7370
#
# WE'LL CONTINUE TO KEEP YOU
# UPDATED.
# 7373
#
# THANK YOU, CHRIS.
# >>> EUROPEANS ARE CLOSELY
# 7375
#
# WATCHING A NATURAL GAS DISPUTE
# BETWEEN RUSSIA AND UKRAINE,
# 7378
#
# BECAUSE IT MAY WELL LEAVE
# EUROPEANS OUT IN THE COLD.
# 7381
#
# >> THAT'S WORRYING THEM.
# RUSSIA HAS SHUT DOWN THE FLOW OF
# 7384
#
# NATURAL GAS TO UKRAINE AFTER
# KIEV REFUSED TO AGREE TO A HEFTY
# 7387
#
# PRICE HIKE.
# >> EUROPEANS ARE WORRIED, THE
# 7392
#
# SAME PIPELINE THAT IS TAKE THAT
# NATURAL GAS FROM RUSSIA TO
# 7394
#
# UKRAINE CONTINUE ON TO WESTERN
# EUROPE.
# 7399
#
# >> FRANCE, HUNGARY,, NOW THE
# DISPUTE HAS TAKEN A NASTY TURN.
# 7400
#
# BRIAN CHILCOTE EXPLAINS.
# >> Reporter: THE GAS WAR, AS
# 7409
#
# IT'S NOW KNOWN, BETWEEN RUSSIA
# AND THE FORMER SOVIET REPUBLIC
# 7413
#
# OF UKRAINE IS HEATING UP,
# SENDING SHIVERS ACROSS EUROPE.
# 7417
#
# RUSSIA CUT OFF GAS SUPPLIES TO
# THE UKRAINE ON NEW YEAR'S DAY
# 7420
#
# OVER A DISPUTE OVER PRICES, THEN
# ON MONDAY ACCUSED UKRAINE
# 7424
#
# STEALING GAS FROM THE PIPELINE
# THAT CARRIES GAS TO CUSTOMERS IN
# 7429
#
# WESTERN EUROPE.
# >> THE AMOUNT OF GAS STOLEN ON
# 7433
#
# JANUARY 1st FROM THE UKRAINE IS
# AROUND 100 MILLION CUBIC METERS
# 7436
#
# WITH A MARKET PRICE OF OVER $25
# MILLION U.S.
# 7441
#
# THE VALUE OF THIS TOLL IN GOODS
# WILL BE EXTREMELY SIGNIFICANT IF
# 7447
#
# IT CONTINUES.
# >> Reporter: SOME UKRAINIAN
# 7451
#
# OFFICIALS SAY THEY WILL TAKE
# SOME OF RUSSIA'S EUROPE BOUND
# 7453
#
# EXPORTS IF THE TEMPERATURE DROPS
# A FEW DEGREES ABOVE FREEZING,
# 7457
#
# BUT IT WON'T BE STEALING, THEY
# SAY.
# 7461
#
# IT WILL BE EXTRACTING PAYMENT.
# RUSSIA CUT OFF GAS SALES TO THE
# 7462
#
# COLORADO UKRAINE AFTER THE KIEV
# GOVERNMENT REFUSE TODAY PAY WHAT
# 7469
#
# RUSSIA CALLS MARKET RATE FOR
# FUEL.
# 7473
#
# IT'S MORE THAN DOUBLE THE RATE
# THEY HAD PAID.
# 7476
#
# IT'S PUNISHMENT, UKRAINE SAYS,
# FOR ITS ORANGE REVOLUTION AND
# 7479
#
# DESIRE TO DEVELOP CLOSER TIES TO
# THE WEST.
# 7484
#
# IT CALLS IT ATTEMPTS TO
# UNDERMINE THE ECONOMY AND
# 7486
#
# BLACKMAIL.
# THE UKRAINE IS BELIEVE TODAY
# 7490
#
# HAVE ENOUGH GAS IN ITS OWN
# RESERVES TO GET THROUGH THE
# 7492
#
# WINTER.
# WESTERN COUNTRY'S RESERVE OF
# 7495
#
# PATIENCE IS RUNNING DRY.
# THE UNITED STATES AND EUROPEAN
# 7499
#
# UNION, WHICH GETS A QUARTER OF
# THE GAS IT NEEDS HAVE CALLED FOR
# 7501
#
# A SPEEDY RESOLUTION.
# WHAT'S BEEN CALLED THE COLDEST
# 7505
#
# WINTER IN YEARS, SOME COUNTRIES
# HAVE EXPERIENCED A DROP IN
# 7510
#
# SUPPLIES FROM RUSSIA.
# RUSSIA SAYS IT HAS A PLAN BUT IS
# 7516
#
# NOT ANNOUNCING DETAIL.
# >> TO ENSURE THE ENERGY SECURITY
# 7519
#
# OF EUROPE, WE HAVE TAKEN ALL
# NECESSARY MEASURES TO RESTORE
# 7522
#
# THE EXPERT LEVELS.
# >> Reporter: BUT THE REASSURANCE
# 7525
#
# HAS DONE LITTLE TO EASE FEARS
# THAT WITH EVERY WINTER DAY THE
# 7528
#
# BATTLEGROUND EXPANDS AND THE
# COST OF THE RUSSIA UKRAINIAN GAS
# 7532
#
# WAR GETS A LITTLE BIGGER.
# BRIAN CHILCOTE, CNN, MOSCOW.
# 7536
#
# KEYS OUT OF THE TRASH SHEET,
# SOMETHING SHE'LL PUT UNDER DPLAS
# 10544
#
# AND HANG ON A WALL, A REMINDER
# OF HOW THE HURRICANE SILENCED
# 10551
#
# THE MUSIC.
# >>> JUST ENOUGH TIME BEFORE WE
# 10555
#
# GO TO CHECK THE INBOX.
# >> WHAT STORY DO YOU WANT US TO
# 10557
#
# COVER MORE IN 2006?
# >> JACQUELINE FROM SWITZERLAND
# 10560
#
# WRITES PIRACY DID NOT DISAPPEAR
# WITH BLACKBEARD.
# 10564
#
# IT IS A CRIME OUT OF CONTROL AND
# HUNDREDS DIE EVERY YEAR AS A
# 10569
#
# RESULT.
# >> LEONARD GARLAND WRITES THIS,
# 10572
#
# PLEASE PROVIDE MORE REPORTS ON
# THE ENVIRONMENTAL SCIENCE BEHIND
# 10575
#
# NATURAL CATASTROPHES WE HAVE
# EXPERIENCED AND WILL PROBABLY
# 10579
#
# CONTINUE TO EXPERIENCE AS A
# RESULT OF GLOBAL WARMING.
# 10582
#
# >> WE GOT SPACE PROGRAMS, A
# SUGGESTION FROM ROBERT.
# 10584
#
# >> TWO PEOPLE SAID MORE ON
# AFRICA AND THE CORRUPT OFFICIALS
# 10589
#
# WHO HAVE BEEN EXPOSED.
# >> GLOBAL STORY BS INNOVATION
# 10592
#
# FROM ROBERT IN SWITZERLAND.
# >> DOMESTIC SPYING IN THE U.S.
# 10594
#
# AND THE VALERIE PLAME LEAK FROM
# PETER IN NORTH CAROLINA.
# 10597
#
# >> STEVE IN THE UNITED STATES
# SUGGESTED ECONOMIC EFFECTS OF
# 10601
#
# GLOBALIZATION IS A GOOD IDEA.
# >> AN EX-PATRIOT LIVING IN
# 10605
#
# GERMANY, JUST ONE WORD STORY.
# CRICKET.
# 10609
#
# WANTS TO HEAR MORE CRICKET.
# >> QUICKLY WE WANT TO UPDATE YOU
# 10612
#
# IN ON THE SITUATION IN SOUTHERN
# GERMANY.
# 10616
#
# OF COURSE, WE'VE BEEN TELLING
# YOU ABOUT THE ROOF THAT
# 10618
#
# COLLAPSED AS A RESULT OF HEAVY
# SNOW FALL.
# 10620
#
# THAT WAS AN ICE SKATING RINK IN
# BAD REICHENHALL.
# 10622
#
# 50 PEOPLE WERE THOUGHT TO BE
# INSIDE.
# 10629
#
# ONE MAN DIED, A WOMAN DIED AND
# AN 8-YEAR-OLD CHILD.
# 10632
#
# 25 WERE INJURED, ABOUT 20 ARE
# STILL MISSING.
# 10635
#
# >>> THAT'S "YOUR WORLD TODAY."
# THE NEWS CONTINUES HERE ON CNN.
# 10638
#
# ORAIOURCHOLESROL'S ILAL...
# 10656
#
# BUIT'S CREEPING UP
# 10658
#
#  WE EAT BETT, EXERCI..
# 10659
#
# AND WE TE
# E-A-DACHOLTEL US
# 10661
#
# <i>THE LYOMPLE LTITAM</i>
# 10663
#
# WI PICOSANOLNDEY
# <i>NUIENTS...</i>
# 10665
#
# TOELP MAININ HEAHYCHOLESROD BLO.
# <i>E-A-Y OLTEL PL.</i>
# 10669
#
# >>> THAT'S ABOUT 100 MILES
# NORTHEAST OF CHARLESTON.
# 10865
#
# THERE'S NO WORD YET ON THE
# CONDITION OF THE MINERS AND
# 10868
#
# THERE'S NO IMMEDIATE INFORMATION
# ABOUT WHAT CAUSED THE BLAST.
# 10871
#
# A SPECIALLY-TRAINED RESCUE TEAM
# WAS HEADING TO THAT MINE PV
# 10874
#
# CARRIE JONES IS IN WEST VIRGINIA
# AND JOINS US BY PHONE.
# 10879
#
# CARRIE, WHAT CAN YOU TELL US
# ABOUT THOSE TRAPPED MINERS?
# 10884
#
# >> RIGHT NOW THE RESCUE MISSION
# HAS BEEN STOPPED BECAUSE
# 10886
#
# EVERYONE HAS BEEN EVACUATED FROM
# THE AREA BECAUSE OF HIGH LEVELS
# 10889
#
# OF METHANE GAS FROM THE MINES
# AND JUST STANDING NEAR THE GAS
# 10893
#
# IS VERY, VERY STRONG.
# BEFORE ANYONE CAN ATTEMPT TO GET
# 10896
#
# DOWN IN THE SHAFT TO RESCUE THE
# 13 MINERS, THEY HAVE TO MAKE
# 10899
#
# SURE THAT THE MINE IS SAFE.
# THEY'RE NOT GOING TO BE SENDING
# 10903
#
# ANYBODY RIGHT NOW BECAUSE OF ALL
# OF THE GAS LEAKING.
# 10906
#
# THEY DO HAVE A FAN TRYING TO GET
# AS MUCH OF IT OUT, NOT ONLY TO
# 10909
#
# PROTECT THE RESCUE WORKERS, BUT
# THE MINERS WHO ARE DOWN THERE
# 10913
#
# RIGHT NOW.
# SIX MINERS WERE RECOVERED RIGHT
# 10917
#
# AFTER THE BLAST HAPPENED THIS
# MORNING, BUT THEY DID REFUSE
# 10919
#
# TREATMENT.
# >> CARRIE, THOSE MINERS THAT ARE
# 10922
#
# STILL TRAPPED HAS BEEN BEEN ABLE
# TO COMMUNICATE WITH ANY OF THEM
# 10926
#
# DOWN THERE?
# >> Reporter: THAT'S SOMETHING
# 10930
#
# THEY'RE TRYING TO TACKLE RIGHT
# NOW BECAUSE THEY HAVE NO
# 10931
#
# COMMUNICATION WITH THEM
# WHATSOEVER.
# 10934
#
# THERE'S NOT SURE OF THEIR
# LOCATION.
# 10937
#
# THEY DO KNOW THEY'RE AT LEAST A
# COUPLE OF MILES BACK.
# 10939
#
# THAT'S WHAT THEY'RE TRYING TO
# TACKLE RIGHT NOW IS FINDING OUT
# 10943
#
# EXACTLY WHERE THEY ARE BECAUSE
# OF THE LACK OF COMMUNICATION.
# 10945
#
# >> YOU'RE TALKING ABOUT METHANE
# GAS THREAT.
# 10947
#
# DO YOU HAVE ANY IDEA WHAT CAUSED
# THIS EXPLOSION?
# 10949
#
# WHAT EXPLODED, ANY OF YOUR
# SOURCES TELLING YOU ANY DETAILS?
# 10952
#
# >> SOME OF THE PEOPLE I TALKED
# TO SAY THE METHANE GAS IS USED
# 10955
#
# TO THAT BECAUSE IT IS NATURALLY
# FORMING AND THERE ARE CERTAIN
# 10958
#
# LEVELS THAT CAN BE THERE, BUT
# IT'S JUST SO MUCH.
# 10962
#
# THEY'RE PRETTY SURE THAT'S WHAT
# THE OVERLOAD OF THE METHANE GAS
# 10967
#
# WHAT CAUSED THE EXPLOSION.
# CARRIE JONES WITH OUR AFFILIATE
# 10971
#
# WDTV, KEEP US UPDATED.
# THANKS SO MUCH.
# 10975
#
# >>> OTHER TOP STORY, RAIN IN THE
# WEST, IF CALIFORNIANS ARE TRYING
# 10978
#
# TO GET A YEAR'S WORTH OF YUCKY
# WEATHER OUT OF THE WAY EARLY,
# 10984
#
# THEY'RE OFF TO A GREAT START.
# THE WEEKEND FLOODS NORTH OF THE
# 10987
#
# BAY AREA ARE GIVING WAY TO
# DOWNPOURS IN AND AROUND LOS
# 10990
#
# ANGELES.
# FOUR MORE INCHES OF NEW RAIN
# 10994
#
# EXPECTED BY TONIGHT.
# THAT MEANS A LOT MORE MUD AND A
# 10995
#
# HIGH RISK OF MORE SCENES LIKE
# THIS ONE.
# 10997
#
# EARLIER, WILDFIRES STRIPPED AWAY
# HUNDRED OF ACRES OF TREES AND
# 11000
#
# BRUSH THAT WOULD HOLD THE SOIL
# IN PLACE.
# 11005
#
# SPEAKING OF THE HILLS, GO UP
# HIGH ENOUGH AND YOU'LL HIT SNOW
# 11007
#
# AND NOT THE FLUFFY
# SKIER-FRIENDLY TYPE STUFF, BUT
# 11010
#
# HEAVY, WET FLAKESTHAT LOCALS
# CALL SIERRA CEMENT.
# 11013
#
# THREE TO FIVE MORE FEET OF THAT
# SNOW ARE EXPECTED ON TOP OF TWO
# 11017
#
# TO THREE FETAL READY ON THE
# GROUND.
# 11020
#
# LET'S START IN MARIN COUNTY AND
# THAT 6 TOWN WHERE SEVEN INCHES
# 11023
#
# OF RAIN SENT FOUR FEET OF WATER
# THROUGH 80 BUSINESSES.
# 11029
#
# YOU CAN JUST IMAGINE THAT MESS.
# YOU DON'T HAVE TO.
# 11032
#
# CNN'S KATHERINE BEAR SET THERE.
# TELL US WHAT YOU'RE SEEING,
# 11035
#
# KATHERINE.
# >> Reporter: IT IS QUITE A MESS.
# 11039
#
# YOU CAN SEE BEHIND ME THE DUMP
# TRUCKS AND LOADERS THAT ARE
# 11042
#
# LIFTING SOD AND COUCH CUSHIONS,
# WRECKED CARPETING, MATTRESSES
# 11046
#
# AND CLOTHING, THE CONTENTS OF
# SOME OF THOSE 80 BUSINESSES UP
# 11050
#
# AND DOWN THIS STREET WHERE SAN
# ANSELMO CREEK JUMPED ITS BANKS
# 11053
#
# AND SOAKED BUSINESSES UP TO FOUR
# FEET IN THESE STOREFRONTS, IN
# 11059
#
# HOMES IN RESIDENCES NONE OF
# THESE BUSINESSES ON THE MAIN
# 11063
#
# STREET ARE OPEN FOR BUSINESS
# TODAY.
# 11068
#
# SOME ARE OPEN TO BE CLEANING OUT
# THROWING OUT THE CLUTTER AND
# 11070
#
# ASSESSING THE DAMAGE.
# WE SPOKE TO THE OWNER OF BUBBA'S
# 11074
#
# DINE OR THE MAIN STREET HERE AND
# HE SAID HE'S IN HIS THIRD DAY OF
# 11077
#
# CLEANUP AND STILL HAS A WEEK
# MORE TO GO BEFORE HE EXPECTS TO
# 11081
#
# REOPEN FOR BUSINESS AND THAT, HE
# SAYS IS AHEAD OF SCHEDULE, BUT
# 11084
#
# HE PUTS HIS OWN LOSS, PERHAPS AT
# $20,000.
# 11087
#
# TOWN OFFICIALS ESTIMATE SAN
# ANSELMO COULD LOSE -- OR COULD
# 11090
#
# COST BUSINESSES HERE BETWEEN 20
# AND $30 MILLION.
# 11096
#
# THE CONSEQUENCE OF THIS FLOODING
# FOR THEM.
# 11098
#
# BUT THEY ARE CLEANING UP TODAY.
# THIS MAIN STREET IS KORTONED OFF
# 11101
#
# BY POLICE TO LET RESIDENTS TAKE
# THE TIME AND HEAVY EQUIPMENT TO
# 11106
#
# CLEAN UP AND DUMP OUT, ABOUT
# WE'VE HAVE HAD TO THROW OUT
# 11110
#
# THINGS AS HUGE AS REFRIGERATOR
# FREEZERS, DISPLAY CASES, REALLY
# 11113
#
# A LOT OF LOSSES FOR THE
# BUSINESSES HERE ALONG THIS
# 11119
#
# STREET, BUT AT LEAST IT'S DRYING
# OUT.
# 11122
#
# THE RAIN HERE HAS SLOWED TO A
# SLOW DRIZZLE FOR THE MOMENT, AT
# 11124
#
# LEAST AND PEOPLE ARE TRYING TO
# PICK UP THE PIECES AND GET ON,
# 11128
#
# KYRA?
# >> AS YOU HEAR ABOUT
# 11131
#
# REFRIGERATORS YOU HEAR ABOUT NEW
# ORLEANS AND THE PROBLEMS THEY
# 11134
#
# HAVE.
# DID A LOT OF PEOPLE RIDE THIS
# 11136
#
# OUT?
# I HEARD THAT IT HAPPENED SO FAST
# 11137
#
# A LOT OF FOLKS DIDN'T HAVE THE
# TIME TO GET OUT.
# 11139
#
# DID YOU SEE THE SAME THING?
# >> Reporter: WELL, THE BUSINESS
# 11141
#
# WE'RE MONITORING WHAT HAPPENED
# TO WHATEVER COMES OUT OF THE
# 21294
#
# MINE.
# >> WHAT IS IT TELL YOU NOW?
# 21299
#
# >> OUR LEVELS ARE DROPPING AND
# IT MAY BE PRETTY SOON WE'LL BE
# 21301
#
# SENDING PEOPLE UNDERGROUND, MINE
# RESCUE TEAMS UNDERGROUND TO
# 21306
#
# EXPLORE AND SEE WHAT WE'VE GOT.
# >> DO YOU HAVE A FIRE THAT YOU
# 21310
#
# HAVE TO CONTEND WITH IT?
# >> THAT, WE DON'T KNOW.
# 21312
#
# >> YOU WON'T BE ABLE TO FIND OUT
# UNTIL, WHAT, UNTIL YOU ACTUALLY
# 21316
#
# ARE ABLE TO GO INTO THE MINE?
# WILL THAT'S CORRECT.
# 21320
#
# BECAUSE THAT'S ONE REASON WHY
# WE'RE MONITORING THE ATMOSPHERE.
# 21322
#
# >> DOUG, LET ME DEAL WITH THIS
# ISSUE OF THE SAFETY OF THAT MINE
# 21328
#
# AND LET ME READ THIS TO YOU.
# THIS IS FROM THE ASSOCIATED
# 21331
#
# PRESS.
# INFORMATION WE HAVE BEEN ABLE TO
# 21335
#
# CONFIRM AS WELL.
# THIS PARTICULAR MINE, THE SAGO
# 21337
#
# MINE, CITED BY FEDERAL
# INSPECTORS FOR 46, 46 ALLEGED
# 21340
#
# VIOLATION OF FEDERAL MINE,
# HEALTH AND SAFETY RULES DURING
# 21344
#
# AN 11-WEEK REVIEW THAT ENDED IN
# DECEMBER.
# 21349
#
# DECEMBER 22, TO BE EXACT.
# WHAT CAN YOU TELL US ABOUT THE
# 21353
#
# HEALTH AND SAFETY OF THAT MINE?
# >> WELL, WE FORM PERFORMED
# 21356
#
# NUMEROUS INSPECTS AT THIS MINE
# AS WELL.
# 21361
#
# I'M CERTAIN THAT THERE WERE
# VIOLATIONS -- I'D HAVE TO LOOK
# 21362
#
# AT THOSE AND SEE WHAT THOSE ARE
# AT THIS POINT.
# 21366
#
# YOU KNOW, SEE WHAT THEY MEAN,
# WHAT VIOLATIONS THEY WERE.
# 21370
#
# THE GRAFT OF THE VIOLATIONS AND
# SO FORTH SO MAKE A DETERMINATION
# 21375
#
# AT THAT LEVEL.
# >> THIS IS -- ARE YOU SUGGESTING
# 21380
#
# THAT THIS IS NEWS TO YOU?
# YOU WERE AWARE OF THESE
# 21383
#
# VIOLATIONS?
# >> YEAH.
# 21386
#
# WHAT I'M SAYING IS, IT'S NOT
# UNUSUAL FOR AN UNDERGROUND COAL
# 21387
#
# MINE TO BE CITED.
# INSPECTORS ARE IN THE MEAN
# 21392
#
# VIRTUALLY EVERY DAY, EVERY OTHER
# DAY, I DON'T KNOW WHAT THE
# 21396
#
# FREQUENCY OF THIS LOCATION ARE
# RIGHT NOW.
# 21401
#
# BUT THAT'S NOT AN UNUSUAL THING.
# >> NOT AN UNUSUAL THING.
# 21404
#
# OUR UNDERSTANDING FUR THAT IS 26
# OF THESE ISSUES HAVE NOT BEEN
# 21409
#
# ASSESSED BY THE COMPANY.
# ARE YOU AWARE OF THAT IN?
# 21413
#
# >> WELL YOU'RE TALKING ABOUT THE
# FEDERAL VIOLATIONS NOW?
# 21416
#
# >> YES.
# >> THAT'S A PROCEED DUR THAT --
# 21421
#
# A SEPARATE STATE AGENCY.
# I'M NOT SURE WHAT YOU ARE
# 21423
#
# REFERRING TO.
# >> DOUG, DO YOU HAVE -- WHAT IS
# 21426
#
# THE RELATIONSHIP -- I UNDERSTAND
# THIS IS A COMPANY THAT YOU
# 21428
#
# HAVE -- YOU'RE DEALING WITH A
# NEW COMPANY IN OWNERSHIP OF THIS
# 21432
#
# MINE.
# AND THE INTERNATIONAL COAL GROUP
# 21435
#
# WHAT HAS BEEN THE STATE'S
# RELATIONSHIP WITH THIS NEW
# 21438
#
# ORGANIZATION, THIS NEW GROUP?
# >> WELL, WE HAVE HAD SEVERAL NEW
# 21440
#
# MINES START UP, NEW COMPANIES
# START UP.
# 21444
#
# THAT'S A RELATIVELY PROMINENT
# OCCURRENCE HERE LATELY IN THE
# 21447
#
# COAL BUSINESS.
# NOTHING UNUSUAL AT THIS POINT
# 21453
#
# WITH THE OPERATION.
# BUT THERE'S A LOT OF ACQUIRING,
# 21457
#
# ONE COMPANY ACQUIRING A
# PARTICULAR MINE.
# 21458
#
# THAT HAPPENS QUITE A BIT HERE
# LATELY.
# 21461
#
# >> THANKS TO DOUG CONOWAY WITH
# THE WEST VIRGINIA OFFICE OF
# 21463
#
# HEALTH, SAFETY AND TRAINING.
# MORE TO COME.
# 21468
#
# >> THANKS SO MUCH.
# WE'LL TAKE A QUICK BREAK.
# 21471
#
# MORE "LIVE FROM" AFTER THIS.
# 21473
#
# RESCUE OPERATION IS UNDERWAY
# THERE.
# 21614
#
# FLASHBACK TO THREE AND A HALF
# YEARS AGO, A GROUP OF MINERS
# 21617
#
# TRAPPED FOR 77 HOURS IN
# PENNSYLVANIA.
# 21620
#
# WE'LL TELL YOU HOW THEY MANAGED
# TO GET OUT ALIVE.
# 21622
#
# I AM TOM FOREMAN.
# AND YOU'RE IN "THE SITUATION
# 21625
#
# ROOM."
# 21629
#
# >>> WE BEGIN WITH A DEVELOPING
# STORY OUT OF WEST VIRGINIA.
# 21644
#
# AL EARLY MORNING EXPLOSION AS
# MINERS WERE DESCENDING FOR THE
# 21647
#
# FIRST SHIFT AT A MINE NEAR BUCK
# HANNON IN THE NORTHEASTERN PART
# 21652
#
# OF THE STATE.
# 12 WERE TRAPPED MORE THAN A MILE
# 21657
#
# BENEATH THE GROUND.
# THERE HAS BEEN NO CONTACT WITH
# 21660
#
# THESE MISSING MINERS AND THE
# RESCUE OPERATION IS BEING
# 21663
#
# HAMPERED BY HIGH LEVELS OF
# DEADLY METHANE GAS.
# 21667
#
# STEVE MILL GAN IS THE EMERGENCY
# DIRECTOR AND JOINS US BY PHONE.
# 21671
#
# TELL US WHAT THE LATEST IS ON
# THESE FOLKS.
# 21676
#
# >> YES, THE RESCUE CREW HAS
# ENTER THE MINE TO TRY TO RESCUE
# 21679
#
# THE MINERS.
# THEY'RE DOING ALL THEY CAN TO
# 21684
#
# GET TO THE MINER AT THIS TIME.
# STILL NO COMMUNICATION AT ALL
# 21686
#
# FROM THE MINERS.
# >> DO YOU HAVE ANY SENSE, STEVE,
# 21690
#
# ARE THEY GOING IN THROUGH
# EXISTING SHAFTS AND TRYING TO
# 21693
#
# CUT THROUGH PILES OF RUBBLE OR
# IS THIS A SITUATION WHERE YOU'LL
# 21696
#
# BE LOOKING AT CUTTING A NEW
# SHAFT?
# 21701
#
# >> RIGHT NOW THEY'RE GOING
# THROUGH THE ORIGINAL ENTRANCE OF
# 21702
#
# THE MINE, A LITTLE MORE THAN A
# MILE FROM THE MINE PORTAL INTO
# 21707
#
# THE PLACE IT HAPPENED.
# AS FAR AS HOW FAR DEEP
# 21713
#
# UNDERGROUND THAT IS AFTER YOU GO
# IN A MILE IN, IT'S HARD TO SAY.
# 21717
#
# YOU GO DOWN AT SOME DEPTH AND
# THEN GO A MILE UNDERGROUND TO
# 21720
#
# WHERE THE COLLAPSE IS.
# >> WE DON'T HAVE A CLEAR
# 21725
#
# INDICATION AT THIS POINT HOW
# MUCH EARTH IS BETWEEN THE
# 21729
#
# COLLAPSED AREA AND WHERE YOU
# WOULD HOPE THESE MEN ARE?
# 21733
#
# >> CORRECT, WE DON'T KNOW FOR
# SURE.
# 21735
#
# >> AND WHAT HAPPENS IN A
# SITUATION LIKE THIS, FROM YOUR
# 21737
#
# EXPERIENCE?
# WILL THERE BE A STEADY WORKING
# 21740
#
# AROUND THE CLOCK ON THAT AREA,
# OR WILL THIS BE SOMETHING THAT
# 21742
#
# THEY ATTEMPT FOR NINE, TEN, 12
# HOURS AND IF THEY'RE MAKING NO
# 21744
#
# REAL PROGRESS AND SEEING NOTHING
# BUT COLLAPSE AHEAD OF THEM, THEY
# 21749
#
# BACK OFF AND RECONSIDER?
# WHAT HAPPENS?
# 21752
#
# >> I WOULD ASSUME THEY WORK AS
# LONG AS THEY CAN.
# 21754
#
# THEY ARE CURRENTLY LOOKING AT
# THE MAPS OF THE MINE, WHICH I'M
# 21756
#
# TOLD ARE UPDATED ON A REGULAR
# BASIS, MAYBE EVEN DAILY.
# 21759
#
# YOU COULD ASSUME THAT IF THEY
# KNEW WHERE THAT COLLAPSE WAS,
# 21763
#
# THEY WOULD SHIFT TO THE SURFACE,
# THEY MAY BE ABLE TO GO DOWN TO
# 21767
#
# THAT POINT.
# THAT SITUATION AND INITIALLY
# 21771
#
# THEY'RE GOING TO TRY TO GO IN
# THROUGH THE EXISTING SHAFT AND
# 21773
#
# TRY TO GET TO THE MINERS THAT
# WAY.
# 21777
#
# >> SO IS THERE ANY REASONABLE
# GUESS AT THIS POINT, WHEN WE'RE
# 21778
#
# TALKING ABOUT THE DISTANCE
# BETWEEN FROM WHERE THEY ARE AND
# 21783
#
# WHERE THE MINERS MIGHT BE, EVEN
# THOUGH IT MAY BE A VERY BROAD
# 21785
#
# RANGE, WHAT IS THE RANGE OF
# POSSIBILITY?
# 21789
#
# >> SAY THAT AGAIN?
# >> WHAT IS THE RANGE OF
# 21792
#
# POSSIBILITY FROM WHERE THE
# RESCUERS ARE AND WHERE THESE MEN
# 21795
#
# MIGHT BE IF THEY ARE ALIVE?
# >> AT LEAST ONE MILE FROM THE
# 21798
#
# ENTRANCE OF THE MINE TO WHERE
# THE MINERS ARE.
# 21802
#
# AS FAR AS WHEN YOU GET TO THE
# WALL OF DEBRIS, HOW FAR BACK IN,
# 21804
#
# I HAVE NO IDEA.
# >> NOBODY REALLY KNOWS AT THIS
# 21810
#
# POINT.
# MY UNDERSTANDING IS THIS
# 21812
#
# HAPPENED AT ABOUT 8:00 THIS
# MORNING AND OTHER MINERS WERE
# 21814
#
# HEADED IN AT THE TIME WHEN THEY
# HEARD THIS EXPLOSION.
# 21816
#
# IS THAT YOUR UNDERSTANDING?
# WHAT ELSE CAN YOU TELL US ABOUT
# 21819
#
# THE EVENTS AT THAT TIME.
# >> THE CALL CAME INTO THE
# 21821
#
# EMERGENCY SERVICES AROUND 7:30.
# IT HAPPENED SOME POINT BEFORE
# 21824
#
# THAT TIME, BUT IT WOULD TAKE
# SOME TIME FOR THE MINERS TO GET
# 21829
#
# BACK OUT TO THE SHAFT TO CALL
# FOR HELP.
# 21832
#
# AS FAR AS WHETHER THEY HAD TO GO
# INTO THE MINOR COMING OUT, I
# 21834
#
# DON'T KNOW THAT EXACTLY.
# >> SO THE ONLY PEOPLE TO COME
# 21838
#
# OUT WERE THE PEOPLE GOING IN FOR
# THAT SHIFT AND THEY CAME OUT
# 21841
#
# COMPLETELY ON THEIR OWN AND THEN
# CAUSED FOR HELP.
# 21844
#
# THERE'S BEEN NO COMMUNICATION
# WITH THE OTHER MEN BEHIND?
# 21846
#
# >> THAT'S MY UNDERSTANDING, YES.
# >> WHAT DO YOU DO AT THIS POINT
# 21849
#
# TO PREPARE FOR THE
# AROUND-THE-CLOCK OPERATION?
# 21853
#
# YOU CERTAINLY HAVE TO HAVE MANY
# PEOPLE CONVERGING ON THAT AREA
# 21857
#
# AND HAVE TO KEEP THE RESCUERS UP
# FOR DOING THE JOB AT THEIR VERY
# 21860
#
# BEST.
# >> YEAH, ONE THING THE RED CROSS
# 21865
#
# IS AT A LOCAL CHURCH HELPING
# WITH THE FAMILIES AND THERE ARE
# 21867
#
# MENTALLAL HEALTH PROFESSIONALS
# ON THE SCENE.
# 21873
#
# WE HAVE A COMMAND POST SET UP.
# THE MINERS THEMSELVES, THE
# 21874
#
# COMPANY AND THE RESCUE CREWS ARE
# TAKING CARE OF THEMSELVES INSIDE
# 21879
#
# THE GATE AS FAR AS WE KNOW.
# BUT WE HAVE FIREFIGHTERS ON
# 21883
#
# SCENES TO DIRECT TRAFFIC AND
# WE'RE BRINGING FOOD INTO THE
# 21888
#
# RESCUERS.
# AS FAR AS LOCAL FIRE, POLICE,
# 21892

# %% [markdown]
# ## Parsing for show names

# %% [markdown]
# #### Raw checking

# %%
show_names = ['CHANNEL 4 NEWS','NIGHTLY NEWS','EXTRA','ACCESS HOLLYWOOD','NEWSROOM','WORLD TODAY','LIVEFROM','LIVE FROM','LIVE-FROM','SITUATION ROOM','LOU DOBBS']
for sub in subs:
    time = list(sub.start)
    time = time[2] + 60*time[1] + 3600*time[0]
    for show in show_names[5:]:
        if show in sub.text:
            print(sub.text)
            print(sec2HMS(time))
            print()
            
#Nouns
#MS-celeb train, filter list of journalists
# Out:
# DEADLY ASK DESTRUCTIVE FLAMES.
# WE ARE LIVE FROM THE FIRE LINES.
# 00:30:28
#
# HE'S JOINING US LIVE FROM OUR
# LONDON BUREAU.
# 01:47:00
#
# TRAVEL TRENDS FOR 2006 AT THE
# TOP OF THE HOUR ON "LIVE FROM."
# 02:26:59
#
# MEANWHILE "YOUR WORLD TODAY"
# CONTINUES AFTER A QUICK BREAK.
# 02:27:04
#
# THIS IS "YOUR WORLD TODAY".
# >> OUR HOUR OF INTERNATIONAL
# 02:45:26
#
# A LOOK AT RESTOREATION EFFORTS
# WHEN "YOUR WORLD TODAY"
# 02:50:14
#
# >>> THAT'S "YOUR WORLD TODAY."
# THE NEWS CONTINUES HERE ON CNN.
# 02:57:18
#
# BRINGING IT TO YOU.
# MORE LIVE FROM" RIGHT AFTER
# 03:13:54
#
# YOU THROUGHOUT THE AFTERNOON ON
# "LIVE FROM."
# 03:19:58
#
# WE'LL STAY ON THE STORY.
# "LIVE FROM" IS BACK AFTER A
# 03:25:09
#
# WE'LL TAKE A QUICK BREAK.
# MORE "LIVE FROM" RIGHT AFTER
# 03:34:15
#
# >> SUZANNE MALVEAUX, LIVE FROM
# THE WHITE HOUSE.
# 03:41:24
#
# WE'LL GET HER STORY.
# "LIVE FROM" IS BACK AFTER A
# 03:41:36
#
# HIS RETURN TO THE U.S.
# STRAIGHT AHEAD ON "LIVE FROM."
# 03:48:59
#
# "LIVE FROM" IS BACK RIGHT AFTER
# A QUICK BREAK.
# 03:54:18
#
# WE'LL KEEP BRINGING IT TO YOU.
# MORE "LIVE FROM" AFTER THIS.
# 04:14:08
#
# THE END OF WORLD WAR II?
# WE'LL TELL YOU WHEN "LIVE FROM"
# 04:21:16
#
# "LIVE FROM" IS GOING TO TAKE A
# QUICK BREAK.
# 04:30:31
#
# COMPLETE CHAOS.
# THAT STORY NEXT ON "LIVE FROM."
# 04:38:21
#
# IMPORTANT TO HER.
# "LIVE FROM" IS BACK RIGHT AFTER
# 04:49:56
#
# AT TOP OF THE 1:00 EASTERN HOUR
# OF "LIVE FROM".
# 05:00:44
#
# "LIVE FROM" HAS ALL OF THE NEWS
# YOU NE.
# 05:50:46
#
# MORE "LIVE FROM" AFTER THIS.
# 05:57:53
#
# YOU'RE IN "THE SITUATION ROOM."
# 06:14:48
#
# SITUATION ROOM."
# WE UNDERSTAND THE MINE IS BEING
# 06:18:17
#
# AND THEIR FAMILIES.
# YOU'RE IN "THE SITUATION ROOM."
# 06:43:34
#
# SITUATION ROOM."
# ABOUT 6:PO THIS MORNING, THERE
# 06:46:21
#
# YOU'RE IN "THE SITUATION ROOM."
# MUCH MORE IS COMING UP.
# 06:51:33
#
# YOU ARE IN "THE SITUATION ROOM."
# 06:56:33
#
# YOU'RE IN THE "SITUATION ROOM."
# NEWS AND INFORMATION FROM AROUND
# 06:59:59
#
# I'M TOM FOREMAN, YOU'RE IN THE
# "SITUATION ROOM."
# 07:00:35
#
# THE "SITUATION ROOM."
# MANY MORE STORIES WE'RE KEEPING
# 07:35:30
#
# STICK WITH US.
# YOU'RE IN THE "SITUATION ROOM."
# 07:49:14
#
# CHRISTINE ROMANS IS FILLING IN
# FOR LOU DOBBS, STANDING BY IN
# 08:00:22

# %% [markdown]
# #### Rule based extraction of show names

# %%
patterns = ['YOU\'RE WATCHING','YOU ARE WATCHING','AFTER THE BREAK','AFTER THIS BREAK','WE ARE BACK','WE\'RE BACK','COMING UP ON','COMING RIGHT UP ON','NEXT ON','CONTINUES AFTER THE BREAK','AFTER THE BREAK','THANKS FOR WATCHING','THANK YOU FOR WATCHING','THANK YOU FOR JOINING ME','RETURNS AFTER THIS']

# %%
for sub in subs:
    for pattern in patterns:
        if pattern in sub.text:
            time = list(sub.start)
            time = time[2] + 60*time[1] + 3600*time[0]
            print(sub)
            print(sec2HMS(time))
            print()
# Out:
# 1580
# 01:51:59,045 --> 01:52:01,847
# AS THEY APPROACH RETIREMENT AGE.
# WE'RE BACK AFTER THIS.
#
# 01:51:59
#
# 3843
# 04:38:21,918 --> 04:38:26,455
# COMPLETE CHAOS.
# THAT STORY NEXT ON "LIVE FROM."
#
# 04:38:21
#
# 5346
# 06:23:18,975 --> 06:23:21,643
# I KNOW YOU'RE WATCHING US.
# YOU'RE LISTENING TO ALL THE
#
# 06:23:18

# %% [markdown]
# ## NLTK Named entity recognition

# %%
os.chdir('my_project/')

# %%
#https://gist.github.com/troyane/c9355a3103ea08679baf
from nltk.tag.stanford import StanfordNERTagger
st = StanfordNERTagger('stanford-ner/english.all.3class.distsim.crf.ser.gz', 'stanford-ner/stanford-ner.jar')
#print (st.tag('You can call me Billiy Bubu and I live in Amsterdam.'.split()))

# %%
def getPeople(text):
    """Returns full names of *people* found in the text"""
    all_tags = st.tag(text.split())
    size = len(all_tags)
    people = []
    count = 0
    is_curr_person = False #If the previous words were 'PERSON'
    while (count<size): #Consecutive words with 'PERSON' tag
        if all_tags[count][1] == 'PERSON':
            if is_curr_person:
                people[-1].append(all_tags[count][0])
            else:
                is_curr_person = True
                people.append([all_tags[count][0]])
        else:
            is_curr_person = False
        count +=1
    
    people = [' '.join(person) for person in people]
    return people

# %%
people = getPeople(full_srt)

# %%
people[:10]
# Out:
# ['ASSAD',
#  'RAFIK HARIRI',
#  'FARRIS HASSAN',
#  'DARYN KAGAN',
#  'JEN RODGERS',
#  'JEN RODGERS',
#  'KATHERINE BARRETT',
#  'DARYN',
#  'KATHERINE BARRETT',
#  'RINGO']

# %% [markdown]
# ## Word presence - inference

# %%
names = ['DARYN','KAGAN','KYRA','PHILLIPS','ROSEMARY','CHURCH','FOREMAN','CHRISTINE','ROMANS']
for n in names:
    for p in people:
        if n in p:
            print(p)

# %%
show_hints = ['WELCOME TO', 'YOU\'RE WATCHING', 'THIS IS', 'TONIGHT ON', '' ]
for sub in subs:
    if 'I\'M' in sub.text:
        for hint in show_hints:
            if hint in sub.text:
                print(sub.text)
                print(sub.start)
                print()
# Out:
#     THIS IS MY HEART
# THAT I'M MAKING HEALTHY.
# 00:15:33,266
#
# I'M ROSALEE CHURCH.
# >> THIS IS YOUR "YOUR WORLD
# 02:00:44,637
#
#     THIS IS MY HEART
# THAT I'M MAKING HEALTHY.
# 04:15:15,233

# %%
def word_count(string):
    counts = dict()
    words = string.split()

    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    return counts

# %%
words_counted = sorted(word_count(full_srt).items(), key = lambda x: -x[1])

# %%
names = ['DARYN','KAGAN','KYRA','PHILLIPS','ROSEMARY','CHURCH','FOREMAN','CHRISTINE','ROMANS']
for x in words_counted:
    for name in names:
        if name in x[0]:
            print(x)

# %%
for x in subs:
    greeting = 'I\'M'
    if greeting in x.text:
        print(x.text)
        print(x.start.to_time())
        print()

# %%
for x in subs:
    for name in names:
        greeting = 'I\'M '+name 
        if greeting in x.text:
            print(x.text)
            print(x.start.to_time())

# %%
for x in subs:
    for name in names[2:]: 
        if name in x.text:
            print(x.text)
            print(x.start.to_time())

# %% [markdown]
# ## Azure trial

# %%
import requests
# If you are using a Jupyter notebook, uncomment the following line.
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
from io import BytesIO
import os
import json

# Replace <Subscription Key> with your valid subscription key.
subscription_key = "8c7905bebc374835aeb117b453b0b540"
assert subscription_key

# You must use the same region in your REST call as you used to get your
# subscription keys. For example, if you got your subscription keys from
# westus, replace "westcentralus" in the URI below with "westus".
#
# Free trial subscription keys are generated in the "westcentralus" region.
# If you use a free trial subscription key, you shouldn't need to change
# this region.
vision_base_url = "https://westcentralus.api.cognitive.microsoft.com/vision/v2.0/"

analyze_url = vision_base_url + "analyze"

# Set image_path to the local path of an image that you want to analyze.
for img in os.listdir('azure-samples/'):
    image_path = 'azure-samples/'+img

    # Read the image into a byte array
    image_data = open(image_path, "rb").read()
    headers = {'Ocp-Apim-Subscription-Key': subscription_key,
               'Content-Type': 'application/octet-stream'}
    params = {'visualFeatures': 'Categories,Description,Color'}
    response = requests.post(
        analyze_url, headers=headers, params=params, data=image_data)
    response.raise_for_status()

    # The 'analysis' object contains various fields that describe the image. The most
    # relevant caption for the image is obtained from the 'description' property.
    analysis = response.json()
    print(json.dumps(analysis, indent=4))
    print()
    image_caption = analysis["description"]["captions"][0]["text"].capitalize()

    # Display the image and overlay it with the caption.
    # image = Image.open(BytesIO(image_data))
    # plt.imshow(image)
    # plt.axis("off")
    # _ = plt.title(image_caption, size="x-large", y=-0.1)
    plt.close('all')
# Out:
# {
#     "categories": [
#         {
#             "name": "others_",
#             "score": 0.0078125
#         },
#         {
#             "name": "people_",
#             "score": 0.6015625,
#             "detail": {
#                 "celebrities": [
#                     {
#                         "name": "Daryn Kagan",
#                         "confidence": 0.9999701976776123,
#                         "faceRectangle": {
#                             "left": 200,
#                             "top": 191,
#                             "width": 250,
#                             "height": 250
#                         }
#                     }
#                 ]
#             }
#         },
#         {
#             "name": "people_portrait",
#             "score": 0.35546875,
#             "detail": {
#                 "celebrities": [
#                     {
#                         "name": "Daryn Kagan",
#                         "confidence": 0.9999701976776123,
#                         "faceRectangle": {
#                             "left": 200,
#                             "top": 191,
#                             "width": 250,
#                             "height": 250
#                         }
#                     }
#                 ]
#             }
#         }
#     ],
#     "color": {
#         "dominantColorForeground": "Black",
#         "dominantColorBackground": "Black",
#         "dominantColors": [
#             "Black"
#         ],
#         "accentColor": "137FB8",
#         "isBwImg": false,
#         "isBWImg": false
#     },
#     "description": {
#         "tags": [
#             "indoor",
#             "person",
#             "woman",
#             "orange",
#             "table",
#             "smiling",
#             "front",
#             "sitting",
#             "holding",
#             "monitor",
#             "wearing",
#             "television",
#             "young",
#             "glasses",
#             "restaurant",
#             "standing",
#             "white",
#             "red",
#             "room",
#             "phone",
#             "plate",
#             "pizza",
#             "food",
#             "man"
#         ],
#         "captions": [
#             {
#                 "text": "Daryn Kagan smiling for the camera",
#                 "confidence": 0.9076624581268251
#             }
#         ]
#     },
#     "requestId": "a137aaa6-e7a8-4be7-a501-7aae3e6cf3a0",
#     "metadata": {
#         "width": 616,
#         "height": 597,
#         "format": "Png"
#     }
# }
#
# {
#     "categories": [
#         {
#             "name": "people_portrait",
#             "score": 0.8203125,
#             "detail": {
#                 "celebrities": [
#                     {
#                         "name": "Christine Romans",
#                         "confidence": 0.9960893392562866,
#                         "faceRectangle": {
#                             "left": 119,
#                             "top": 240,
#                             "width": 285,
#                             "height": 285
#                         }
#                     }
#                 ]
#             }
#         }
#     ],
#     "color": {
#         "dominantColorForeground": "Brown",
#         "dominantColorBackground": "Blue",
#         "dominantColors": [
#             "Blue",
#             "Brown",
#             "Teal"
#         ],
#         "accentColor": "17B49F",
#         "isBwImg": false,
#         "isBWImg": false
#     },
#     "description": {
#         "tags": [
#             "woman",
#             "monitor",
#             "lady",
#             "holding",
#             "smiling",
#             "posing",
#             "standing",
#             "girl",
#             "blue",
#             "white",
#             "young",
#             "sign"
#         ],
#         "captions": [
#             {
#                 "text": "Christine Romans smiling for the camera",
#                 "confidence": 0.8546662002775072
#             }
#         ]
#     },
#     "requestId": "dab60723-eca1-4bd9-893f-05b756efd32e",
#     "metadata": {
#         "width": 565,
#         "height": 622,
#         "format": "Png"
#     }
# }
#
# {
#     "categories": [
#         {
#             "name": "people_portrait",
#             "score": 0.8203125,
#             "detail": {
#                 "celebrities": [
#                     {
#                         "name": "Christine Romans",
#                         "confidence": 0.9960893392562866,
#                         "faceRectangle": {
#                             "left": 119,
#                             "top": 240,
#                             "width": 285,
#                             "height": 285
#                         }
#                     }
#                 ]
#             }
#         }
#     ],
#     "color": {
#         "dominantColorForeground": "Brown",
#         "dominantColorBackground": "Blue",
#         "dominantColors": [
#             "Blue",
#             "Brown",
#             "Teal"
#         ],
#         "accentColor": "17B49F",
#         "isBwImg": false,
#         "isBWImg": false
#     },
#     "description": {
#         "tags": [
#             "woman",
#             "monitor",
#             "lady",
#             "holding",
#             "smiling",
#             "posing",
#             "standing",
#             "girl",
#             "blue",
#             "white",
#             "young",
#             "sign"
#         ],
#         "captions": [
#             {
#                 "text": "Christine Romans smiling for the camera",
#                 "confidence": 0.8546662002775072
#             }
#         ]
#     },
#     "requestId": "b851e525-25da-495d-833a-f01cb489e457",
#     "metadata": {
#         "width": 565,
#         "height": 622,
#         "format": "Png"
#     }
# }
#
# {
#     "categories": [
#         {
#             "name": "people_",
#             "score": 0.43359375,
#             "detail": {
#                 "celebrities": [
#                     {
#                         "name": "Kyra Phillips",
#                         "confidence": 0.9994309544563293,
#                         "faceRectangle": {
#                             "left": 179,
#                             "top": 199,
#                             "width": 235,
#                             "height": 235
#                         }
#                     }
#                 ]
#             }
#         },
#         {
#             "name": "people_portrait",
#             "score": 0.53515625,
#             "detail": {
#                 "celebrities": [
#                     {
#                         "name": "Kyra Phillips",
#                         "confidence": 0.9994309544563293,
#                         "faceRectangle": {
#                             "left": 179,
#                             "top": 199,
#                             "width": 235,
#                             "height": 235
#                         }
#                     }
#                 ]
#             }
#         }
#     ],
#     "color": {
#         "dominantColorForeground": "Brown",
#         "dominantColorBackground": "Brown",
#         "dominantColors": [
#             "Brown"
#         ],
#         "accentColor": "3C8B8F",
#         "isBwImg": false,
#         "isBWImg": false
#     },
#     "description": {
#         "tags": [
#             "person",
#             "woman",
#             "indoor",
#             "lady",
#             "front",
#             "holding",
#             "standing",
#             "smiling",
#             "girl",
#             "restaurant",
#             "young",
#             "table",
#             "food",
#             "bus",
#             "pizza",
#             "phone",
#             "white",
#             "shirt",
#             "train",
#             "red",
#             "plate",
#             "people"
#         ],
#         "captions": [
#             {
#                 "text": "Kyra Phillips smiling for the camera",
#                 "confidence": 0.9285889532565311
#             }
#         ]
#     },
#     "requestId": "38e5d8c0-b3b0-4e3f-9992-462b73fe4f0f",
#     "metadata": {
#         "width": 587,
#         "height": 560,
#         "format": "Png"
#     }
# }
#
# {
#     "categories": [
#         {
#             "name": "people_",
#             "score": 0.45703125,
#             "detail": {
#                 "celebrities": [
#                     {
#                         "name": "Kyra Phillips",
#                         "confidence": 0.9997994303703308,
#                         "faceRectangle": {
#                             "left": 124,
#                             "top": 194,
#                             "width": 247,
#                             "height": 247
#                         }
#                     }
#                 ]
#             }
#         },
#         {
#             "name": "people_portrait",
#             "score": 0.5390625,
#             "detail": {
#                 "celebrities": [
#                     {
#                         "name": "Kyra Phillips",
#                         "confidence": 0.9997994303703308,
#                         "faceRectangle": {
#                             "left": 124,
#                             "top": 194,
#                             "width": 247,
#                             "height": 247
#                         }
#                     }
#                 ]
#             }
#         }
#     ],
#     "color": {
#         "dominantColorForeground": "Brown",
#         "dominantColorBackground": "Black",
#         "dominantColors": [
#             "Brown",
#             "Black"
#         ],
#         "accentColor": "2993A2",
#         "isBwImg": false,
#         "isBWImg": false
#     },
#     "description": {
#         "tags": [
#             "indoor",
#             "person",
#             "woman",
#             "holding",
#             "front",
#             "girl",
#             "blue",
#             "young",
#             "hair",
#             "smiling",
#             "standing",
#             "table",
#             "white",
#             "room",
#             "red",
#             "shirt",
#             "phone",
#             "pizza"
#         ],
#         "captions": [
#             {
#                 "text": "Kyra Phillips smiling for the camera",
#                 "confidence": 0.8730262626104458
#             }
#         ]
#     },
#     "requestId": "b7e5ef78-7d76-430c-9187-976fef865b5a",
#     "metadata": {
#         "width": 503,
#         "height": 571,
#         "format": "Png"
#     }
# }
# {
#     "categories": [
#         {
#             "name": "people_",
#             "score": 0.3203125,
#             "detail": {
#                 "celebrities": [
#                     {
#                         "name": "Christine Romans",
#                         "confidence": 0.999870777130127,
#                         "faceRectangle": {
#                             "left": 180,
#                             "top": 231,
#                             "width": 280,
#                             "height": 280
#                         }
#                     }
#                 ]
#             }
#         },
#         {
#             "name": "people_portrait",
#             "score": 0.67578125,
#             "detail": {
#                 "celebrities": [
#                     {
#                         "name": "Christine Romans",
#                         "confidence": 0.999870777130127,
#                         "faceRectangle": {
#                             "left": 180,
#                             "top": 231,
#                             "width": 280,
#                             "height": 280
#                         }
#                     }
#                 ]
#             }
#         }
#     ],
#     "color": {
#         "dominantColorForeground": "Brown",
#         "dominantColorBackground": "Blue",
#         "dominantColors": [
#             "Blue",
#             "Brown"
#         ],
#         "accentColor": "14B794",
#         "isBwImg": false,
#         "isBWImg": false
#     },
#     "description": {
#         "tags": [
#             "woman",
#             "monitor",
#             "smiling",
#             "posing",
#             "television",
#             "lady",
#             "photo",
#             "screen",
#             "front",
#             "holding",
#             "standing",
#             "white",
#             "girl",
#             "blue",
#             "black",
#             "young",
#             "wearing",
#             "purple",
#             "computer"
#         ],
#         "captions": [
#             {
#                 "text": "Christine Romans smiling for the camera",
#                 "confidence": 0.9088174827323177
#             }
#         ]
#     },
#     "requestId": "0cba8fbc-8a61-4094-9872-09a23a052548",
#     "metadata": {
#         "width": 649,
#         "height": 619,
#         "format": "Png"
#     }
# }
