# %% [markdown]
# ## Setup

# %%
# !export PYTHONUSERBASE=$HOME/.usr/local/python/2.7.13

# %%
#insightFace ==> https://github.com/deepinsight/insightface/tree/master/recognition
# !git clone --recursive https://github.com/deepinsight/insightface.git

# %%
#https://github.com/deepinsight/insightface/issues/338
# !pip install --user scipy sklearn
# !pip install --user mxnet
# !pip install --user mxnet-cu90
# !pip install --user easydict
# !pip install --user opencv-python
# !pip install --user pillow
# !pip install --user pandas
# Out:
# Traceback (most recent call last):
#   File "/usr/local/gcc-6_3_0/openmpi-2_0_1/python2/2.7.13/bin/pip", line 7, in <module>
#     from pip import main
# ImportError: cannot import name main
# Traceback (most recent call last):
#   File "/usr/local/gcc-6_3_0/openmpi-2_0_1/python2/2.7.13/bin/pip", line 7, in <module>
#     from pip import main
# ImportError: cannot import name main
# Traceback (most recent call last):
#   File "/usr/local/gcc-6_3_0/openmpi-2_0_1/python2/2.7.13/bin/pip", line 7, in <module>
#     from pip import main
# ImportError: cannot import name main
# Traceback (most recent call last):
#   File "/usr/local/gcc-6_3_0/openmpi-2_0_1/python2/2.7.13/bin/pip", line 7, in <module>
#     from pip import main
# ImportError: cannot import name main
# Traceback (most recent call last):
#   File "/usr/local/gcc-6_3_0/openmpi-2_0_1/python2/2.7.13/bin/pip", line 7, in <module>
#     from pip import main
# ImportError: cannot import name main
# Traceback (most recent call last):
#   File "/usr/local/gcc-6_3_0/openmpi-2_0_1/python2/2.7.13/bin/pip", line 7, in <module>
#     from pip import main
# ImportError: cannot import name main
# Traceback (most recent call last):
#   File "/usr/local/gcc-6_3_0/openmpi-2_0_1/python2/2.7.13/bin/pip", line 7, in <module>
#     from pip import main
# ImportError: cannot import name main

# %%
# Check if GPU allotted
#!nvidia-smi

# %%
# %cd insightface/recognition/
# Out:
# /mnt/rds/redhen/gallina/home/skb78/insightface/recognition

# %%
# !cp sample_config.py config.py

# %%
# !CUDA_VISIBLE_DEVICES='0' python -u train.py --network r100 --loss arcface --dataset retina

# %%
# !ls MS-Celeb-1M/data/croped_face_images/

# %%
# %%writefile tsv_extractor.py
import os
import base64
import struct

fid = open("MS-Celeb-1M/data/croped_face_images/FaceImageCroppedWithOutAlignment.tsv", "r")
base_path = 'MS-Celeb-1M/data/croped_face_images/extracted_images'
if not os.path.exists(base_path):
  os.mkdir(base_path)
bbox_file = open(base_path + '/bboxes.txt', 'w')
count = 0
while True:
  if(count%10000==0):
    print count
  count += 1
  if(count<4000000): #hardcoded
    continue
  line = fid.readline()
  if line:
    data_info = line.split('\t')
    # 0: Freebase MID (unique key for each entity)
    # 1: ImageSearchRank
    # 4: FaceID
    # 5: bbox
    # 6: img_data
    filename = data_info[0] + "/" + data_info[1] + "_" + data_info[4] + ".jpg"
    bbox = struct.unpack('ffff', data_info[5].decode("base64"))
    bbox_file.write(filename + " "+ (" ".join(str(bbox_value) for bbox_value  in bbox)) + "\n")

    img_data = data_info[6].decode("base64")
    output_file_path = base_path + "/" + filename 
#     if os.path.exists(output_file_path):
#       print output_file_path + " exists"

    output_path = os.path.dirname(output_file_path)
    if not os.path.exists(output_path):
      os.mkdir(output_path)
    
    if (len(os.listdir(output_path))<5):
        if not os.path.exists(output_file_path):
            #print output_file_path
            img_file = open(output_file_path, 'w')
            img_file.write(img_data)
            img_file.close()
  else:
    break

bbox_file.close()
fid.close()
# Out:
# Overwriting tsv_extractor.py

# %%
% cd /home/skb78/gallinahome/MS_Celeb_uncropped/
# Out:
# /mnt/rds/redhen/gallina/home/skb78/MS_Celeb_uncropped

# %%
#EXPERIMENTATION ONLY
import os
import base64
import struct

fid = open("MS-Celeb-1M/data/croped_face_images/FaceImageCroppedWithOutAlignment.tsv", "r")
base_path = 'MS-Celeb-1M/data/croped_face_images/extracted_images'
# if not os.path.exists(base_path):
#   os.mkdir(base_path)
# bbox_file = open(base_path + '/bboxes.txt', 'w')
ALL_IDS = set()
count = 0
while True:
  if(count%10000==0):
    print count
  count += 1
#   if(count<4000000): #hardcoded
#     continue
  line = fid.readline()
  if line:
    data_info = line.split('\t')
    # 0: Freebase MID (unique key for each entity)
    # 1: ImageSearchRank
    # 4: FaceID
    # 5: bbox
    # 6: img_data
    filename = data_info[0] + "/" + data_info[1] + "_" + data_info[4] + ".jpg"
#     bbox = struct.unpack('ffff', data_info[5].decode("base64"))
#     bbox_file.write(filename + " "+ (" ".join(str(bbox_value) for bbox_value  in bbox)) + "\n")

#     img_data = data_info[6].decode("base64")
    output_file_path = base_path + "/" + filename 
#     if os.path.exists(output_file_path):
#       print output_file_path + " exists"

    output_path = os.path.dirname(output_file_path)
    ALL_IDS.add(output_path)
  else:
    break
# Out:
# m.0107_f
# 0
# http://getbeatmadrid.files.wordpress.com/2013/01/magic-alex.jpg
# http://getbeatmadrid.wordpress.com/2013/01/28/magic-alex/
# FaceId-0
# KsQsP3Pumj2B6UE/Vj4/Pg==
# ()
# m.0107_f
# 1
# http://1.bp.blogspot.com/-HNFIL7eKdNs/TxnlvZvisvI/AAAAAAAAANE/AsNempI4Efc/s1600/magicalex.jpg
# http://plasticineportal.blogspot.com/2012/01/magic-alexs-statement.html
# FaceId-0
# voT2Po1YFz5oL0E/qqqqPg==
# ()
# m.0107_f
# 2
# http://www.magicalex.cz/wp-content/gallery/kouzla/magic_alex.jpg
# http://www.magicalex.cz/fotogalerie/
# FaceId-0
# SLTCPgAAqD51oxg/mpnxPg==
# ()
# m.0107_f
# 3
# http://2.bp.blogspot.com/_71dhc6LM1i4/SBSPDqHtjPI/AAAAAAAAAVg/rFWbkmqfo2Q/s200/magic_alex.jpg
# http://lifeofthebeatles.blogspot.com/2006/06/many-faces-of-magic-alex-mardas.html
# FaceId-0
# Cu2lPs3MjD57CS0/exTuPg==
# ()
# m.0107_f
# 4
# http://www.magicalex.cz/wp-content/uploads/2013/02/Magic-Alex-foto-2013.jpg
# http://www.magicalex.cz/magic-alex-miri-na-televizni-obrazovky/
# FaceId-0
# HAqVPjlJfD7x6/8+7prYPg==
# ()
# m.0107_f
# 5
# http://1.bp.blogspot.com/_KeXeLMoyB8E/TOEZGj0VDzI/AAAAAAAAAEQ/ph8N28hJzwE/s1600/magic_alex_Gregresized.jpg
# http://magicalexdjs.blogspot.com/2010/11/it-was-very-good-year.html
# FaceId-0
# TMHaPkrRwz4zyw8/PIjvPg==
# ()
# m.0107_f
# 6
# http://stash.alonetone.com/pics/29179/magalex-001.jpg
# http://alonetone.com/magicalex/bio
# FaceId-0
# n+T7PpmZmT4eHh4/j8LVPg==
# ()
# m.0107_f
# 7
# http://arcadesushi.com/files/2013/04/Magic-Alex-Photo-2.jpg
# http://www.bonn.de/umwelt_gesundheit_planen_bauen_wohnen/abfallplaner/stichwortverzeichnis/00170/index.html
# FaceId-0
# 663ePrD4ij5MuRQ/sx/7Pg==
# ()
# m.0107_f
# 8
# http://beatlephotoblog.com/photos/2011/04/188.jpg
# http://beatlephotoblog.com/tag/magic-alex
# FaceId-0
# gfeHPpJ2rD1i5Lk+XOJUPg==
# ()
# m.0107_f
# 8
# http://beatlephotoblog.com/photos/2011/04/188.jpg
# http://beatlephotoblog.com/tag/magic-alex
# FaceId-1
# mnD2Pu5YgT6+LhQ/d6zAPg==
# ()

# %%
'm.01_92n' in ALL_IDS
# Out:
# False

# %%
# !rm -rf MS-Celeb-1M/data/croped_face_images/extracted_images
# !mkdir MS-Celeb-1M/data/croped_face_images/extracted_images
# !python tsv_extractor.py MS-Celeb-1M/data/croped_face_images/FaceImageCroppedWithOutAlignment.tsv --outputDir MS-Celeb-1M/data/croped_face_images/extracted_images

# %%
# %cd ~/gallinahome/MS_Celeb_uncropped/
# Out:
# /mnt/rds/redhen/gallina/home/skb78/MS_Celeb_uncropped

# %%
### Extracting celebrity name using Google Knowledge Graph API
import os
import json
import urllib
import csv
import pandas as pd
#CELEB_INFO1
celeb_dirs = sorted(os.listdir('MS-Celeb-1M/data/croped_face_images/extracted_images/'))[1:]
already_extracted = (pd.read_csv('celeb_info.csv')['id'])
api_key = 'AIzaSyCjDjg1CgXlFtsplYzAA_Duyq4vvW4T9_A'

count = len(already_extracted) + len(pd.read_csv('celeb_info1.csv')['id']) + len(pd.read_csv('celeb_info2.csv')['id'])
max_itr = len(celeb_dirs)
fail_streak = 0
names_csv = [['id','name','description','article_body']]

print('{} celebs already extracted'.format(count))
while count<max_itr:
    celeb = celeb_dirs[count]
    
    if(count%100==0):
        print(count)
    if not 'm.' in celeb: #making sure dir_name is in the m.1234 format
        continue

    ids = '/'+celeb.replace('.','/')
    
    service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
    params = {
        'ids': ids,
        'limit': 10,
        'indent': True,
        'key': api_key,
    }
    url = service_url + '?' + urllib.urlencode(params)
    response = json.loads(urllib.urlopen(url).read())
    #print(json.dumps(response, indent=4, sort_keys=True))
    try:
        name = response['itemListElement'][0]['result']['name'].encode('ascii','ignore')
#         fail_streak = 0
    except: #Service unavailable, need to retry
        fail_streak += 1
        print('Failed for {}'.format(ids))
        if(fail_streak>=5):
            count +=1
            fail_streak=0
        continue
    try:
        description = response['itemListElement'][0]['result']['description'].encode('ascii','ignore')
    except:
        description = None
        
    try:
        article_body = response['itemListElement'][0]['result']['detailedDescription']['articleBody'].encode('ascii','ignore')
    except:
        article_body = None
    
    count+=1
    names_csv.append([celeb,name,description,article_body]) # Adding details to the csv_file container
    
with open("celeb_info_final.csv", "wb") as f:
    writer = csv.writer(f)
    writer.writerows(names_csv)
    
#TODO: GET FAILED CELEBS LIST - while changing dir names
# Out:
# 51071 celebs already extracted
# 51100
# 51200
# Failed for /m/05hsjk
# 51300
# Failed for /m/05jhz8
# Failed for /m/05jhz8
# Failed for /m/05jhz8
# Failed for /m/05jhz8
# 51400
# 51500
# 51600
# 51700
# Failed for /m/05m41c
# Failed for /m/05m41c
# Failed for /m/05m41c
# Failed for /m/05m41c
# Failed for /m/05m41c
# Failed for /m/05m7gb
# Failed for /m/05m7gb
# Failed for /m/05m7gb
# Failed for /m/05m7gb
# Failed for /m/05m7gb
# Failed for /m/05m_1nb
# Failed for /m/05m_1nb
# Failed for /m/05m_1nb
# Failed for /m/05m_1nb
# Failed for /m/05m_1nb
# 51800
# 51900
# 52000
# Failed for /m/05mxtqs
# Failed for /m/05mxtqs
# Failed for /m/05mxtqs
# Failed for /m/05mxtqs
# Failed for /m/05mxtqs
# 52100
# 52200
# 52300
# 52400
# 52500
# Failed for /m/05p8396
# Failed for /m/05p8396
# Failed for /m/05p8396
# Failed for /m/05p8396
# Failed for /m/05p8396
# 52600
# 52700
# Failed for /m/05pn6
# Failed for /m/05pn6
# Failed for /m/05pn6
# Failed for /m/05pn6
# Failed for /m/05pn6
# Failed for /m/05pwx5
# Failed for /m/05pwx5
# Failed for /m/05pwx5
# Failed for /m/05pwx5
# Failed for /m/05pwx5
# 52800
# 52900
# 53000
# Failed for /m/05qq_d
# Failed for /m/05qq_d
# Failed for /m/05qq_d
# Failed for /m/05qq_d
# Failed for /m/05qq_d
# 53100
# Failed for /m/05r5j0
# Failed for /m/05r5j0
# Failed for /m/05r5j0
# Failed for /m/05r5j0
# Failed for /m/05r5j0
# 53200
# 53300
# 53400
# 53500
# Failed for /m/05t2xz
# Failed for /m/05t2xz
# Failed for /m/05t2xz
# Failed for /m/05t2xz
# Failed for /m/05t2xz
# 53600
# Failed for /m/05v0gd
# Failed for /m/05v0gd
# Failed for /m/05v0gd
# Failed for /m/05v0gd
# Failed for /m/05v0gd
# 53700
# Failed for /m/05vjlk
# Failed for /m/05vjlk
# Failed for /m/05vjlk
# Failed for /m/05vjlk
# Failed for /m/05vjlk
# 53800
# Failed for /m/05vslll
# Failed for /m/05vslll
# Failed for /m/05vslll
# Failed for /m/05vslll
# Failed for /m/05vslll
# 53900
# 54000
# 54100
# 54200
# 54300
# 54400
# Failed for /m/05ypm2
# Failed for /m/05ypm2
# Failed for /m/05ypm2
# Failed for /m/05ypm2
# Failed for /m/05ypm2
# Failed for /m/05yz1w
# Failed for /m/05yz1w
# Failed for /m/05yz1w
# Failed for /m/05yz1w
# Failed for /m/05yz1w
# 54500
# 54600
# Failed for /m/05zknw8
# Failed for /m/05zknw8
# Failed for /m/05zknw8
# Failed for /m/05zknw8
# Failed for /m/05zknw8
# 54700
# 54800
# Failed for /m/05zsjdp
# Failed for /m/05zsjdp
# Failed for /m/05zsjdp
# Failed for /m/05zsjdp
# Failed for /m/05zsjdp
# 54900
# 55000
# Failed for /m/060h8g
# Failed for /m/060h8g
# Failed for /m/060h8g
# Failed for /m/060h8g
# Failed for /m/060h8g
# 55100
# Failed for /m/0612px
# Failed for /m/0612px
# Failed for /m/0612px
# Failed for /m/0612px
# Failed for /m/0612px
# 55200
# 55300
# 55400
# 55500
# 55600
# 55700
# 55800
# Failed for /m/0642dmv
# Failed for /m/0642dmv
# Failed for /m/0642dmv
# Failed for /m/0642dmv
# Failed for /m/0642dmv
# 55900
# Failed for /m/0649p8
# Failed for /m/0649p8
# Failed for /m/0649p8
# Failed for /m/0649p8
# Failed for /m/0649p8
# Failed for /m/064hmw
# Failed for /m/064hmw
# Failed for /m/064hmw
# Failed for /m/064hmw
# Failed for /m/064hmw
# 56000
# 56100
# Failed for /m/064p0t8
# Failed for /m/064p0t8
# Failed for /m/064p0t8
# Failed for /m/064p0t8
# Failed for /m/064p0t8
# 56200
# 56300
# 56400
# 56500
# 56600
# 56700
# 56800
# 56900
# 57000
# 57100
# 57200
# 57300
# 57400
# 57500
# 57600
# 57700
# 57800
# 57900
# 58000
# 58100
# 58200
# 58300
# Failed for /m/06jsw3
# Failed for /m/06jsw3
# Failed for /m/06jsw3
# Failed for /m/06jsw3
# Failed for /m/06jsw3
# 58400
# Failed for /m/06k697
# Failed for /m/06k697
# Failed for /m/06k697
# Failed for /m/06k697
# Failed for /m/06k697
# Failed for /m/06kh4_
# Failed for /m/06kh4_
# Failed for /m/06kh4_
# Failed for /m/06kh4_
# Failed for /m/06kh4_
# 58500
# 58600
# Failed for /m/06lm5b
# Failed for /m/06lm5b
# Failed for /m/06lm5b
# Failed for /m/06lm5b
# Failed for /m/06lm5b
# Failed for /m/06lrp9
# Failed for /m/06lrp9
# Failed for /m/06lrp9
# Failed for /m/06lrp9
# Failed for /m/06lrp9
# 58700
# Failed for /m/06m35q
# Failed for /m/06m35q
# Failed for /m/06m35q
# Failed for /m/06m35q
# Failed for /m/06m35q
# Failed for /m/06m6cv
# Failed for /m/06m6cv
# Failed for /m/06m6cv
# Failed for /m/06m6cv
# Failed for /m/06m6cv
# 58800
# Failed for /m/06mvqq
# Failed for /m/06mvqq
# Failed for /m/06mvqq
# Failed for /m/06mvqq
# Failed for /m/06mvqq
# 58900
# Failed for /m/06nw9x
# Failed for /m/06nw9x
# Failed for /m/06nw9x
# Failed for /m/06nw9x
# Failed for /m/06nw9x
# 59000
# 59100
# 59200
# 59300
# 59400
# 59500
# 59600
# 59700
# 59800
# 59900
# 60000
# 60100
# 60200
# 60300
# Failed for /m/06wxpr
# Failed for /m/06wxpr
# Failed for /m/06wxpr
# Failed for /m/06wxpr
# Failed for /m/06wxpr
# 60400
# Failed for /m/06xy9l
# Failed for /m/06xy9l
# Failed for /m/06xy9l
# Failed for /m/06xy9l
# Failed for /m/06xy9l
# 60500
# 60600
# 60700
# 60800
# 60900
# 61000
# 61100
# 61200
# 61300
# Failed for /m/072xl
# Failed for /m/072xl
# Failed for /m/072xl
# Failed for /m/072xl
# Failed for /m/072xl
# 61400
# 61500
# 61600
# 61700
# 61800
# 61900
# Failed for /m/076fx2
# 62000
# 62100
# Failed for /m/076zmsm
# Failed for /m/076zmsm
# Failed for /m/076zmsm
# Failed for /m/076zmsm
# 62200
# Failed for /m/077t3p
# Failed for /m/077tpt
# 62300
# 62400
# Failed for /m/078pk7
# 62500
# Failed for /m/079q8w
# 62600
# Failed for /m/07_gb7
# Failed for /m/07_gh2
# 62700
# Failed for /m/07_nmc
# 62800
# Failed for /m/07bffz
# 62900
# Failed for /m/07cm3h
# Failed for /m/07cm6_
# 63000
# Failed for /m/07cxtq
# Failed for /m/07cxtq
# Failed for /m/07cxtq
# Failed for /m/07cxtq
# Failed for /m/07cxtq
# Failed for /m/07d6f2
# Failed for /m/07d6qn
# Failed for /m/07d6sr
# 63100
# 63200
# Failed for /m/07f5v7
# Failed for /m/07f5v7
# 63300
# Failed for /m/07frzr
# 63400
# Failed for /m/07gr9b
# 63500
# Failed for /m/07hs0h
# Failed for /m/07hs0h
# Failed for /m/07hs0h
# 63600
# 63700
# 63800
# 63900
# 64000
# 64100
# 64200
# Failed for /m/07kvpr
# Failed for /m/07kvpr
# Failed for /m/07kvpr
# Failed for /m/07kvpr
# Failed for /m/07kvpr
# Failed for /m/07l4gg
# Failed for /m/07l4gg
# Failed for /m/07l4gg
# Failed for /m/07l4gg
# Failed for /m/07l4gg
# 64300
# Failed for /m/07lvn
# Failed for /m/07lvn
# Failed for /m/07lvn
# Failed for /m/07lvn
# Failed for /m/07lvn
# 64400
# Failed for /m/07my78
# Failed for /m/07my78
# Failed for /m/07my78
# Failed for /m/07my78
# Failed for /m/07my78
# 64500
# 64600
# Failed for /m/07pcm2
# Failed for /m/07pcm2
# Failed for /m/07pcm2
# Failed for /m/07pcm2
# Failed for /m/07pcm2
# 64700
# Failed for /m/07q07b
# Failed for /m/07q07b
# Failed for /m/07q07b
# Failed for /m/07q07b
# Failed for /m/07q07b
# 64800
# 64900
# Failed for /m/07rsdz
# Failed for /m/07rsdz
# Failed for /m/07rsdz
# Failed for /m/07rsdz
# Failed for /m/07rsdz
# 65000
# 65100
# 65200
# 65300
# 65400
# 65500
# 65600
# 65700
# 65800
# 65900
# 66000
# 66100
# 66200
# 66300
# 66400
# 66500
# 66600
# 66700
# 66800
# 66900
# 67000
# Failed for /m/083ynb
# Failed for /m/083ynb
# Failed for /m/083ynb
# Failed for /m/083ynb
# Failed for /m/083ynb
# 67100
# Failed for /m/085hc8
# Failed for /m/085jp0
# Failed for /m/085jp0
# Failed for /m/085jp0
# Failed for /m/085jp0
# 67200
# Failed for /m/085wk9
# Failed for /m/085wk9
# Failed for /m/085wk9
# Failed for /m/085wk9
# Failed for /m/085wk9
# 67300
# 67400
# 67500
# Failed for /m/088_tv
# Failed for /m/088_tv
# Failed for /m/088_tv
# Failed for /m/088_tv
# Failed for /m/088_tv
# 67600
# 67700
# 67800
# Failed for /m/08_yf5
# Failed for /m/08_yf5
# Failed for /m/08_yf5
# Failed for /m/08_yf5
# Failed for /m/08_yf5
# 67900
# 68000
# 68100
# Failed for /m/08dwb0
# Failed for /m/08dwb0
# Failed for /m/08dwb0
# Failed for /m/08dwb0
# Failed for /m/08dwb0
# 68200
# 68300
# Failed for /m/08gzds
# Failed for /m/08gzds
# Failed for /m/08gzds
# Failed for /m/08gzds
# Failed for /m/08gzds
# 68400
# 68500
# 68600
# Failed for /m/08kkt9
# Failed for /m/08kkt9
# Failed for /m/08kkt9
# Failed for /m/08kkt9
# Failed for /m/08kkt9
# 68700
# 68800
# 68900
# Failed for /m/08mmd_
# Failed for /m/08mmd_
# Failed for /m/08mmd_
# Failed for /m/08mmd_
# Failed for /m/08mmd_
# Failed for /m/08mmxj
# Failed for /m/08mmxj
# Failed for /m/08mmxj
# Failed for /m/08mmxj
# Failed for /m/08mmxj
# 69000
# 69100
# Failed for /m/08phrk
# Failed for /m/08phrk
# Failed for /m/08phrk
# Failed for /m/08phrk
# Failed for /m/08phrk
# Failed for /m/08pjnr
# Failed for /m/08pjnr
# Failed for /m/08pjnr
# Failed for /m/08pjnr
# Failed for /m/08pjnr
# 69200
# 69300
# Failed for /m/08rwv0
# Failed for /m/08rwv0
# Failed for /m/08rwv0
# Failed for /m/08rwv0
# Failed for /m/08rwv0
# Failed for /m/08s4t6
# Failed for /m/08s4t6
# Failed for /m/08s4t6
# Failed for /m/08s4t6
# Failed for /m/08s4t6
# 69400
# Failed for /m/08scqs
# Failed for /m/08scqs
# Failed for /m/08scqs
# Failed for /m/08scqs
# Failed for /m/08scqs
# Failed for /m/08spsn
# Failed for /m/08spsn
# Failed for /m/08spsn
# Failed for /m/08spsn
# Failed for /m/08spsn
# 69500
# 69600
# Failed for /m/08w95x
# Failed for /m/08w95x
# Failed for /m/08w95x
# Failed for /m/08w95x
# Failed for /m/08w95x
# 69700
# Failed for /m/08ww0z
# Failed for /m/08ww0z
# Failed for /m/08ww0z
# Failed for /m/08ww0z
# Failed for /m/08ww0z
# 69800
# 69900
# 70000
# 70100
# 70200
# 70300
# Failed for /m/092lj8
# Failed for /m/092lj8
# Failed for /m/092lj8
# Failed for /m/092lj8
# Failed for /m/092lj8
# Failed for /m/0936kg
# Failed for /m/0936kg
# Failed for /m/0936kg
# Failed for /m/0936kg
# Failed for /m/0936kg
# 70400
# 70500
# 70600
# Failed for /m/095p0v
# Failed for /m/095p0v
# Failed for /m/095p0v
# Failed for /m/095p0v
# Failed for /m/095p0v
# 70700
# 70800
# 70900
# Failed for /m/09907c
# Failed for /m/09907c
# Failed for /m/09907c
# Failed for /m/09907c
# Failed for /m/09907c
# 71000
# Failed for /m/099hqk
# Failed for /m/099hqk
# Failed for /m/099hqk
# Failed for /m/099hqk
# Failed for /m/099hqk
# 71100
# 71200
# Failed for /m/09c1lw
# Failed for /m/09c1lw
# Failed for /m/09c1lw
# Failed for /m/09c1lw
# Failed for /m/09c1lw
# Failed for /m/09c1r3
# Failed for /m/09c1r3
# Failed for /m/09c1r3
# Failed for /m/09c1r3
# Failed for /m/09c1r3
# 71300
# Failed for /m/09cs_x
# Failed for /m/09cs_x
# Failed for /m/09cs_x
# Failed for /m/09cs_x
# Failed for /m/09cs_x
# 71400
# Failed for /m/09dmkg
# Failed for /m/09dmkg
# Failed for /m/09dmkg
# Failed for /m/09dmkg
# Failed for /m/09dmkg
# 71500
# 71600
# 71700
# Failed for /m/09g_9c
# Failed for /m/09g_9c
# Failed for /m/09g_9c
# Failed for /m/09g_9c
# Failed for /m/09g_9c
# 71800
# 71900
# Failed for /m/09ghzh7
# Failed for /m/09ghzh7
# Failed for /m/09ghzh7
# Failed for /m/09ghzh7
# Failed for /m/09ghzh7
# Failed for /m/09ghzx_
# Failed for /m/09ghzx_
# Failed for /m/09ghzx_
# Failed for /m/09ghzx_
# Failed for /m/09ghzx_
# Failed for /m/09gjr1w
# Failed for /m/09gjr1w
# Failed for /m/09gjr1w
# Failed for /m/09gjr1w
# Failed for /m/09gjr1w
# 72000
# Failed for /m/09gn5tv
# Failed for /m/09gn5tv
# Failed for /m/09gn5tv
# Failed for /m/09gn5tv
# Failed for /m/09gn5tv
# 72100
# Failed for /m/09gpqnf
# Failed for /m/09gpqnf
# Failed for /m/09gpqnf
# Failed for /m/09gpqnf
# Failed for /m/09gpqnf
# 72200
# Failed for /m/09hk65
# Failed for /m/09hk65
# Failed for /m/09hk65
# Failed for /m/09hk65
# Failed for /m/09hk65
# 72300
# Failed for /m/09jd5h
# Failed for /m/09jd5h
# Failed for /m/09jd5h
# Failed for /m/09jd5h
# Failed for /m/09jd5h
# 72400
# 72500
# 72600
# 72700
# Failed for /m/09mck0
# Failed for /m/09mck0
# Failed for /m/09mck0
# Failed for /m/09mck0
# Failed for /m/09mck0
# 72800
# 72900
# 73000
# 73100
# Failed for /m/09rtfbk
# Failed for /m/09rtfbk
# Failed for /m/09rtfbk
# Failed for /m/09rtfbk
# Failed for /m/09rtfbk
# 73200
# Failed for /m/09s18s
# Failed for /m/09s18s
# Failed for /m/09s18s
# Failed for /m/09s18s
# Failed for /m/09s18s
# Failed for /m/09s39g
# Failed for /m/09s39g
# Failed for /m/09s39g
# Failed for /m/09s39g
# Failed for /m/09s39g
# 73300
# 73400
# 73500
# 73600
# Failed for /m/09v6rsm
# Failed for /m/09v6rsm
# Failed for /m/09v6rsm
# Failed for /m/09v6rsm
# Failed for /m/09v6rsm
# 73700
# Failed for /m/09vmll
# Failed for /m/09vmll
# Failed for /m/09vmll
# Failed for /m/09vmll
# Failed for /m/09vmll
# 73800
# 73900
# 74000
# 74100
# Failed for /m/09zp9m
# Failed for /m/09zp9m
# Failed for /m/09zp9m
# Failed for /m/09zp9m
# Failed for /m/09zp9m
# 74200
# 74300
# 74400
# 74500
# Failed for /m/0b48jp
# Failed for /m/0b48jp
# Failed for /m/0b48jp
# Failed for /m/0b48jp
# Failed for /m/0b48jp
# 74600
# Failed for /m/0b4lr6
# Failed for /m/0b4lr6
# Failed for /m/0b4lr6
# Failed for /m/0b4lr6
# Failed for /m/0b4lr6
# 74700
# Failed for /m/0b6f5y1
# Failed for /m/0b6f5y1
# Failed for /m/0b6f5y1
# Failed for /m/0b6f5y1
# Failed for /m/0b6f5y1
# 74800
# 74900
# 75000
# 75100
# Failed for /m/0b77132
# 75200
# Failed for /m/0b7b7k
# Failed for /m/0b7b7k
# Failed for /m/0b7b7k
# Failed for /m/0b7b7k
# 75300
# Failed for /m/0b8kwx
# Failed for /m/0b8kwx
# Failed for /m/0b8kwx
# Failed for /m/0b8kwx
# Failed for /m/0b8kwx
# Failed for /m/0b8lny
# Failed for /m/0b8lny
# Failed for /m/0b8lny
# Failed for /m/0b8lny
# Failed for /m/0b8lny
# 75400
# 75500
# Failed for /m/0b_j_n
# Failed for /m/0b_j_n
# Failed for /m/0b_j_n
# Failed for /m/0b_j_n
# Failed for /m/0b_j_n
# 75600
# 75700
# Failed for /m/0bbx48l
# Failed for /m/0bbx48l
# Failed for /m/0bbx48l
# Failed for /m/0bbx48l
# Failed for /m/0bbx48l
# 75800
# 75900
# Failed for /m/0bcrjt
# Failed for /m/0bcrjt
# Failed for /m/0bcrjt
# Failed for /m/0bcrjt
# Failed for /m/0bcrjt
# 76000
# Failed for /m/0bf__4
# Failed for /m/0bf__4
# Failed for /m/0bf__4
# Failed for /m/0bf__4
# Failed for /m/0bf__4
# 76100
# Failed for /m/0bg9vc
# Failed for /m/0bg9vc
# Failed for /m/0bg9vc
# Failed for /m/0bg9vc
# Failed for /m/0bg9vc
# Failed for /m/0bgbqm
# Failed for /m/0bgbqm
# Failed for /m/0bgbqm
# Failed for /m/0bgbqm
# Failed for /m/0bgbqm
# Failed for /m/0bgk6l6
# Failed for /m/0bgk6l6
# Failed for /m/0bgk6l6
# Failed for /m/0bgk6l6
# Failed for /m/0bgk6l6
# 76200
# 76300
# Failed for /m/0bhbm95
# Failed for /m/0bhcc38
# Failed for /m/0bhcc38
# Failed for /m/0bhcc38
# Failed for /m/0bhcc38
# 76400
# Failed for /m/0bjc_h
# Failed for /m/0bjc_h
# Failed for /m/0bjc_h
# Failed for /m/0bjc_h
# Failed for /m/0bjc_h
# 76500
# 76600
# Failed for /m/0bl1xh
# Failed for /m/0bl1xh
# Failed for /m/0bl1xh
# Failed for /m/0bl1xh
# Failed for /m/0bl1xh
# 76700
# Failed for /m/0blsfb
# Failed for /m/0blsfb
# Failed for /m/0blsfb
# Failed for /m/0blsfb
# Failed for /m/0blsfb
# 76800
# 76900
# Failed for /m/0bmjw60
# Failed for /m/0bmjw60
# Failed for /m/0bmjw60
# Failed for /m/0bmjw60
# Failed for /m/0bmjw60
# 77000
# 77100
# 77200
# 77300
# 77400
# 77500
# 77600
# 77700
# 77800
# 77900
# 78000
# Failed for /m/0bwkp49
# Failed for /m/0bwkp49
# Failed for /m/0bwkp49
# Failed for /m/0bwkp49
# Failed for /m/0bwkp49
# 78100
# 78200
# Failed for /m/0bxz9pp
# Failed for /m/0bxz9pp
# Failed for /m/0bxz9pp
# Failed for /m/0bxz9pp
# Failed for /m/0bxz9pp
# 78300
# 78400
# Failed for /m/0bzjjh
# Failed for /m/0bzjjh
# Failed for /m/0bzjjh
# Failed for /m/0bzjjh
# Failed for /m/0bzjjh
# 78500
# 78600
# 78700
# Failed for /m/0c26gg
# Failed for /m/0c26gg
# Failed for /m/0c26gg
# Failed for /m/0c26gg
# Failed for /m/0c26gg
# Failed for /m/0c27ny
# Failed for /m/0c27ny
# Failed for /m/0c27ny
# Failed for /m/0c27ny
# Failed for /m/0c27ny
# 78800
# Failed for /m/0c328f
# Failed for /m/0c328f
# Failed for /m/0c328f
# Failed for /m/0c328f
# Failed for /m/0c328f
# Failed for /m/0c32lz
# Failed for /m/0c32lz
# Failed for /m/0c32lz
# Failed for /m/0c32lz
# Failed for /m/0c32lz
# Failed for /m/0c3c6l
# Failed for /m/0c3c6l
# Failed for /m/0c3c6l
# Failed for /m/0c3c6l
# Failed for /m/0c3c6l
# 78900
# 79000
# 79100
# Failed for /m/0c53_s
# Failed for /m/0c53_s
# Failed for /m/0c53_s
# Failed for /m/0c53_s
# Failed for /m/0c53_s
# 79200
# 79300
# 79400
# 79500
# Failed for /m/0c8mwj
# Failed for /m/0c8mwj
# Failed for /m/0c8mwj
# Failed for /m/0c8mwj
# Failed for /m/0c8mwj
# Failed for /m/0c8q0k
# Failed for /m/0c8q0k
# Failed for /m/0c8q0k
# Failed for /m/0c8q0k
# Failed for /m/0c8q0k
# 79600
# 79700
# 79800
# Failed for /m/0cc5jkm
# Failed for /m/0cc5jkm
# Failed for /m/0cc5jkm
# Failed for /m/0cc5jkm
# Failed for /m/0cc5jkm
# 79900
# 80000
# Failed for /m/0ccnt8
# Failed for /m/0ccnt8
# Failed for /m/0ccnt8
# Failed for /m/0ccnt8
# Failed for /m/0ccnt8
# 80100
# Failed for /m/0cf629
# Failed for /m/0cf629
# Failed for /m/0cf629
# Failed for /m/0cf629
# Failed for /m/0cf629
# 80200
# Failed for /m/0cfx89
# Failed for /m/0cfx89
# Failed for /m/0cfx89
# Failed for /m/0cfx89
# Failed for /m/0cfx89
# Failed for /m/0cghvm
# Failed for /m/0cghvm
# Failed for /m/0cghvm
# Failed for /m/0cghvm
# Failed for /m/0cghvm
# 80300
# 80400
# Failed for /m/0ch4dz
# Failed for /m/0ch4dz
# Failed for /m/0ch4dz
# Failed for /m/0ch4dz
# Failed for /m/0ch4dz
# 80500
# 80600
# 80700
# Failed for /m/0ckghq
# Failed for /m/0ckghq
# Failed for /m/0ckghq
# Failed for /m/0ckghq
# Failed for /m/0ckghq
# Failed for /m/0ckgkt
# Failed for /m/0ckgkt
# Failed for /m/0ckgkt
# Failed for /m/0ckgkt
# Failed for /m/0ckgkt
# 80800
# 80900
# 81000
# Failed for /m/0cmcr3_
# Failed for /m/0cmcr3_
# Failed for /m/0cmcr3_
# Failed for /m/0cmcr3_
# Failed for /m/0cmcr3_
# 81100
# Failed for /m/0cn2z
# Failed for /m/0cn2z
# Failed for /m/0cn2z
# Failed for /m/0cn2z
# Failed for /m/0cn2z
# 81200
# 81300
# 81400
# Failed for /m/0cppb9
# Failed for /m/0cppb9
# Failed for /m/0cppb9
# Failed for /m/0cppb9
# Failed for /m/0cppb9
# 81500
# Failed for /m/0crbw9l
# Failed for /m/0crbw9l
# Failed for /m/0crbw9l
# Failed for /m/0crbw9l
# Failed for /m/0crbw9l
# 81600
# 81700
# Failed for /m/0cs70j
# Failed for /m/0cs70j
# Failed for /m/0cs70j
# Failed for /m/0cs70j
# Failed for /m/0cs70j
# 81800
# 81900
# 82000
# 82100
# 82200
# 82300
# Failed for /m/0czf3zg
# Failed for /m/0czf3zg
# Failed for /m/0czf3zg
# Failed for /m/0czf3zg
# Failed for /m/0czf3zg
# 82400
# 82500
# Failed for /m/0d1009
# Failed for /m/0d1009
# Failed for /m/0d1009
# Failed for /m/0d1009
# Failed for /m/0d1009
# 82600
# Failed for /m/0d2g5y
# Failed for /m/0d2g5y
# Failed for /m/0d2g5y
# Failed for /m/0d2g5y
# Failed for /m/0d2g5y
# 82700
# Failed for /m/0d4m5h
# Failed for /m/0d4m5h
# Failed for /m/0d4m5h
# Failed for /m/0d4m5h
# Failed for /m/0d4m5h
# 82800
# Failed for /m/0d55gk
# Failed for /m/0d55gk
# Failed for /m/0d55gk
# Failed for /m/0d55gk
# Failed for /m/0d55gk
# Failed for /m/0d5dy
# Failed for /m/0d5dy
# Failed for /m/0d5dy
# Failed for /m/0d5dy
# Failed for /m/0d5dy
# 82900
# 83000
# Failed for /m/0d7c7t
# Failed for /m/0d7c7t
# Failed for /m/0d7c7t
# Failed for /m/0d7c7t
# Failed for /m/0d7c7t
# 83100
# 83200
# 83300
# 83400
# 83500
# Failed for /m/0ddcnz4
# Failed for /m/0ddcnz4
# Failed for /m/0ddcnz4
# Failed for /m/0ddcnz4
# Failed for /m/0ddcnz4
# 83600
# 83700
# 83800
# 83900
# 84000
# Failed for /m/0dhxnd
# Failed for /m/0dhxnd
# Failed for /m/0dhxnd
# Failed for /m/0dhxnd
# Failed for /m/0dhxnd
# 84100
# Failed for /m/0dkjjd
# Failed for /m/0dkjjd
# Failed for /m/0dkjjd
# Failed for /m/0dkjjd
# Failed for /m/0dkjjd
# 84200
# Failed for /m/0dlfht
# Failed for /m/0dlfht
# Failed for /m/0dlfht
# Failed for /m/0dlfht
# Failed for /m/0dlfht
# 84300
# 84400
# 84500
# 84600
# 84700
# 84800
# Failed for /m/0drjty
# Failed for /m/0drjty
# Failed for /m/0drjty
# Failed for /m/0drjty
# Failed for /m/0drjty
# Failed for /m/0ds0538
# Failed for /m/0ds0538
# Failed for /m/0ds0538
# Failed for /m/0ds0538
# Failed for /m/0ds0538
# 84900
# 85000
# Failed for /m/0ds8y1p
# Failed for /m/0ds8y1p
# Failed for /m/0ds8y1p
# Failed for /m/0ds8y1p
# Failed for /m/0ds8y1p
# 85100
# 85200
# 85300
# 85400
# Failed for /m/0dxvs
# Failed for /m/0dxvs
# Failed for /m/0dxvs
# Failed for /m/0dxvs
# Failed for /m/0dxvs
# 85500
# 85600
# 85700
# 85800
# 85900
# 86000
# 86100
# 86200
# 86300
# 86400
# 86500
# 86600
# 86700
# 86800
# 86900
# 87000
# 87100
# Failed for /m/0fp93f_
# Failed for /m/0fp93f_
# Failed for /m/0fp93f_
# Failed for /m/0fp93f_
# Failed for /m/0fp93f_
# 87200
# Failed for /m/0fpj4lx
# Failed for /m/0fpj4lx
# Failed for /m/0fpj4lx
# Failed for /m/0fpj4lx
# Failed for /m/0fpj4lx
# 87300
# Failed for /m/0fpj_zx
# Failed for /m/0fpj_zx
# Failed for /m/0fpj_zx
# Failed for /m/0fpj_zx
# Failed for /m/0fpj_zx
# Failed for /m/0fpp0t
# Failed for /m/0fpp0t
# Failed for /m/0fpp0t
# Failed for /m/0fpp0t
# Failed for /m/0fpp0t
# 87400
# 87500
# 87600
# 87700
# 87800
# 87900
# 88000
# 88100
# 88200
# 88300
# 88400
# 88500
# 88600
# 88700
# Failed for /m/0g5hvrt
# Failed for /m/0g5hvrt
# Failed for /m/0g5hvrt
# Failed for /m/0g5hvrt
# Failed for /m/0g5hvrt
# Failed for /m/0g5k2z
# Failed for /m/0g5k2z
# Failed for /m/0g5k2z
# Failed for /m/0g5k2z
# Failed for /m/0g5k2z
# Failed for /m/0g5l30c
# Failed for /m/0g5l30c
# Failed for /m/0g5l30c
# Failed for /m/0g5l30c
# Failed for /m/0g5l30c
# Failed for /m/0g5l30q
# Failed for /m/0g5l30q
# Failed for /m/0g5l30q
# Failed for /m/0g5l30q
# Failed for /m/0g5l30q
# Failed for /m/0g5lv5
# Failed for /m/0g5lv5
# Failed for /m/0g5lv5
# Failed for /m/0g5lv5
# Failed for /m/0g5lv5
# 88800
# Failed for /m/0g5r8wy
# Failed for /m/0g5r8wy
# Failed for /m/0g5r8wy
# Failed for /m/0g5r8wy
# Failed for /m/0g5r8wy
# 88900
# 89000
# 89100
# 89200
# Failed for /m/0g9ws94
# Failed for /m/0g9ws94
# Failed for /m/0g9ws94
# Failed for /m/0g9ws94
# Failed for /m/0g9ws94
# 89300
# 89400
# 89500
# 89600
# Failed for /m/0gcgr1
# Failed for /m/0gcgr1
# Failed for /m/0gcgr1
# Failed for /m/0gcgr1
# Failed for /m/0gcgr1
# 89700
# Failed for /m/0gcst
# Failed for /m/0gcst
# Failed for /m/0gcst
# Failed for /m/0gcst
# Failed for /m/0gcst
# 89800
# 89900
# 90000
# 90100
# Failed for /m/0gg4s_8
# Failed for /m/0gg4s_8
# Failed for /m/0gg4s_8
# Failed for /m/0gg4s_8
# Failed for /m/0gg4s_8
# 90200
# 90300
# 90400
# 90500
# Failed for /m/0gjdnj_
# Failed for /m/0gjdnj_
# Failed for /m/0gjdnj_
# Failed for /m/0gjdnj_
# Failed for /m/0gjdnj_
# 90600
# 90700
# Failed for /m/0gkz8bw
# Failed for /m/0gkz8bw
# Failed for /m/0gkz8bw
# Failed for /m/0gkz8bw
# Failed for /m/0gkz8bw
# 90800
# 90900
# Failed for /m/0glqs_8
# 91000
# Failed for /m/0gmc7y7
# Failed for /m/0gmc7y7
# Failed for /m/0gmc7y7
# Failed for /m/0gmc7y7
# 91100
# 91200
# 91300
# Failed for /m/0gpm8y
# 91300
# 91400
# 91500
# Failed for /m/0gtfv8
# Failed for /m/0gtfv8
# Failed for /m/0gtfv8
# Failed for /m/0gtfv8
# 91600
# 91700
# 91800
# Failed for /m/0gvtvc1
# Failed for /m/0gvtvc1
# Failed for /m/0gvtvc1
# Failed for /m/0gvtvc1
# Failed for /m/0gvtvc1
# 91900
# Failed for /m/0gw_kv5
# Failed for /m/0gw_kv5
# Failed for /m/0gw_kv5
# Failed for /m/0gw_kv5
# Failed for /m/0gw_kv5
# 92000
# Failed for /m/0gwzq5v
# Failed for /m/0gwzq5v
# Failed for /m/0gwzq5v
# Failed for /m/0gwzq5v
# Failed for /m/0gwzq5v
# 92100
# Failed for /m/0gxgdrl
# Failed for /m/0gxgdrl
# Failed for /m/0gxgdrl
# Failed for /m/0gxgdrl
# Failed for /m/0gxgdrl
# 92200
# Failed for /m/0gy2_h
# Failed for /m/0gy2_h
# Failed for /m/0gy2_h
# Failed for /m/0gy2_h
# Failed for /m/0gy2_h
# Failed for /m/0gyqxm
# Failed for /m/0gyqxm
# Failed for /m/0gyqxm
# Failed for /m/0gyqxm
# Failed for /m/0gyqxm
# 92300
# 92400
# 92500
# 92600
# Failed for /m/0h1fnvm
# Failed for /m/0h1fnvm
# Failed for /m/0h1fnvm
# Failed for /m/0h1fnvm
# Failed for /m/0h1fnvm
# Failed for /m/0h1fnzv
# Failed for /m/0h1fnzv
# Failed for /m/0h1fnzv
# Failed for /m/0h1fnzv
# Failed for /m/0h1fnzv
# 92700
# 92800
# Failed for /m/0h2gn9
# 92900
# Failed for /m/0h3mhw7
# Failed for /m/0h3mhw7
# Failed for /m/0h3mhw7
# Failed for /m/0h3mhw7
# 93000
# 93100
# Failed for /m/0h3x557
# Failed for /m/0h3x557
# Failed for /m/0h3x557
# Failed for /m/0h3x557
# Failed for /m/0h3x557
# Failed for /m/0h43j
# 93200
# Failed for /m/0h522vx
# Failed for /m/0h522vx
# Failed for /m/0h522vx
# Failed for /m/0h522vx
# 93300
# 93400
# Failed for /m/0h666zr
# Failed for /m/0h666zr
# Failed for /m/0h666zr
# Failed for /m/0h666zr
# Failed for /m/0h666zr
# 93500
# 93600
# 93700
# 93800
# Failed for /m/0h_98jv
# 93900
# 94000
# Failed for /m/0hgp2dw
# 94100
# 94200
# 94300
# 94400
# Failed for /m/0hnqdsm
# 94500
# Failed for /m/0hrcpw8
# Failed for /m/0hrcpw8
# 94600
# Failed for /m/0hzb8
# Failed for /m/0hzb8
# Failed for /m/0hzb8
# Failed for /m/0hzb8
# Failed for /m/0hzb8
# Failed for /m/0hzcd
# Failed for /m/0hzcd
# Failed for /m/0hzcd
# Failed for /m/0hzcd
# Failed for /m/0hzcd
# 94700
# 94800
# 94900
# Failed for /m/0j2szn7
# Failed for /m/0j2szn7
# Failed for /m/0j2szn7
# Failed for /m/0j2szn7
# Failed for /m/0j2szn7
# 95000
# 95100
# 95200
# Failed for /m/0j63px2
# Failed for /m/0j63px2
# Failed for /m/0j63px2
# Failed for /m/0j63px2
# Failed for /m/0j63px2
# 95300
# 95400
# Failed for /m/0j8f0b8
# Failed for /m/0j8f0b8
# Failed for /m/0j8f0b8
# Failed for /m/0j8f0b8
# Failed for /m/0j8f0b8
# Failed for /m/0j9l0xk
# Failed for /m/0j9l0xk
# Failed for /m/0j9l0xk
# Failed for /m/0j9l0xk
# Failed for /m/0j9l0xk
# 95500
# 95600
# Failed for /m/0j_6p3g
# Failed for /m/0j_6p3g
# Failed for /m/0j_6p3g
# Failed for /m/0j_6p3g
# Failed for /m/0j_6p3g
# 95700
# 95800
# 95900
# 96000
# Failed for /m/0jwwgnw
# Failed for /m/0jwwgnw
# Failed for /m/0jwwgnw
# Failed for /m/0jwwgnw
# Failed for /m/0jwwgnw
# 96100
# 96200
# Failed for /m/0k0vtc9
# 96300
# Failed for /m/0k2bmv4
# 96400
# 96500
# 96600
# 96700
# 96800
# 96900
# Failed for /m/0krrz
# Failed for /m/0krrz
# Failed for /m/0krrz
# Failed for /m/0ks503
# 97000
# 97100
# Failed for /m/0ksq4_
# 97200
# 97300
# 97400
# 97500
# Failed for /m/0lq5svr
# Failed for /m/0lq5svr
# Failed for /m/0lq5svr
# Failed for /m/0lq75yw
# Failed for /m/0lq75yw
# Failed for /m/0lq75yw
# Failed for /m/0lq75yw
# Failed for /m/0lq75yw
# 97600
# Failed for /m/0lv74
# Failed for /m/0lv74
# Failed for /m/0lv74
# Failed for /m/0lv74
# Failed for /m/0lv74
# Failed for /m/0lwnv
# 97700
# 97800
# 97900
# 98000
# 98100
# 98200
# Failed for /m/0nb7qc4
# Failed for /m/0nb7qc4
# Failed for /m/0nb7qc4
# Failed for /m/0nb7qc4
# 98300
# Failed for /m/0ndws1b
# Failed for /m/0ndws1b
# Failed for /m/0ndws1b
# Failed for /m/0ndws1b
# Failed for /m/0ndws1b
# 98400
# Failed for /m/0ngt980
# Failed for /m/0ngt980
# Failed for /m/0ngt980
# Failed for /m/0ngt980
# Failed for /m/0ngt980
# 98500
# Failed for /m/0p3jtrc
# Failed for /m/0p3jtrc
# Failed for /m/0p3jtrc
# Failed for /m/0p3jtrc
# Failed for /m/0p3jtrc
# Failed for /m/0p3rchn
# Failed for /m/0p3rchn
# Failed for /m/0p3rchn
# Failed for /m/0p3rchn
# Failed for /m/0p3rchn
# 98600
# Failed for /m/0pb4908
# Failed for /m/0pb4908
# Failed for /m/0pb4908
# Failed for /m/0pb4908
# Failed for /m/0pb4908
# 98700
# Failed for /m/0pk93
# Failed for /m/0pk93
# Failed for /m/0pk93
# Failed for /m/0pk93
# Failed for /m/0pk93
# Failed for /m/0pk9w
# Failed for /m/0pk9w
# Failed for /m/0pk9w
# Failed for /m/0pk9w
# Failed for /m/0pk9w
# Failed for /m/0pkcc
# Failed for /m/0pkcc
# Failed for /m/0pkcc
# Failed for /m/0pkcc
# Failed for /m/0pkcc
# Failed for /m/0pklc
# Failed for /m/0pklc
# Failed for /m/0pklc
# Failed for /m/0pklc
# Failed for /m/0pklc
# 98800
# Failed for /m/0pmg3f9
# Failed for /m/0pmg3f9
# Failed for /m/0pmg3f9
# Failed for /m/0pmg3f9
# Failed for /m/0pmg3f9
# Failed for /m/0pxyy
# Failed for /m/0pxyy
# Failed for /m/0pxyy
# Failed for /m/0pxyy
# Failed for /m/0pxyy
# 98900
# 99000
# Failed for /m/0qft6yv
# Failed for /m/0qft6yv
# Failed for /m/0qft6yv
# Failed for /m/0qft6yv
# Failed for /m/0qft6yv
# Failed for /m/0qftm4h
# Failed for /m/0qftm4h
# Failed for /m/0qftm4h
# Failed for /m/0qftm4h
# Failed for /m/0qftm4h
# 99100
# Failed for /m/0qzdfc1
# Failed for /m/0qzdfc1
# Failed for /m/0qzdfc1
# Failed for /m/0qzdfc1
# Failed for /m/0qzdfc1
# 99200
# Failed for /m/0r3t1bv
# 99300
# Failed for /m/0rpfv5x
# Failed for /m/0rpfv5x
# Failed for /m/0rpfv5x
# Failed for /m/0rpfv5x
# Failed for /m/0rpgdj5
# Failed for /m/0rpgdj5
# Failed for /m/0rpgdj5
# Failed for /m/0rpgdj5
# Failed for /m/0rpgdj5
# 99400
# 99500
# 99600
# 99700
# Failed for /m/0vzvcp6
# Failed for /m/0vzvcp6
# Failed for /m/0vzvcp6
# Failed for /m/0vzvcp6
# Failed for /m/0vzvcp6
# 99800
# Failed for /m/0x48wd2
# Failed for /m/0x48wd2
# Failed for /m/0x48wd2
# Failed for /m/0x48wd2
# Failed for /m/0x48wd2

# %%
with open("celeb_info2.csv", "wb") as f:
    writer = csv.writer(f)
    writer.writerows(names_csv)

# %%
# %%writefile train.py
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import sys
import math
import random
import logging
import sklearn
import pickle
import numpy as np
import mxnet as mx
from mxnet import ndarray as nd
import argparse
import mxnet.optimizer as optimizer
from config import config, default, generate_config
from metric import *
sys.path.append(os.path.join(os.path.dirname(__file__), '..', 'common'))
import flops_counter
sys.path.append(os.path.join(os.path.dirname(__file__), 'eval'))
import verification
sys.path.append(os.path.join(os.path.dirname(__file__), 'symbol'))
import fresnet
import fmobilefacenet
import fmobilenet
import fmnasnet
import fdensenet


logger = logging.getLogger()
logger.setLevel(logging.INFO)


args = None



def parse_args():
  parser = argparse.ArgumentParser(description='Train face network')
  # general
  parser.add_argument('--dataset', default=default.dataset, help='dataset config')
  parser.add_argument('--network', default=default.network, help='network config')
  parser.add_argument('--loss', default=default.loss, help='loss config')
  args, rest = parser.parse_known_args()
  generate_config(args.network, args.dataset, args.loss)
  parser.add_argument('--models-root', default=default.models_root, help='root directory to save model.')
  parser.add_argument('--pretrained', default=default.pretrained, help='pretrained model to load')
  parser.add_argument('--pretrained-epoch', type=int, default=default.pretrained_epoch, help='pretrained epoch to load')
  parser.add_argument('--ckpt', type=int, default=default.ckpt, help='checkpoint saving option. 0: discard saving. 1: save when necessary. 2: always save')
  parser.add_argument('--verbose', type=int, default=default.verbose, help='do verification testing and model saving every verbose batches')
  parser.add_argument('--lr', type=float, default=default.lr, help='start learning rate')
  parser.add_argument('--lr-steps', type=str, default=default.lr_steps, help='steps of lr changing')
  parser.add_argument('--wd', type=float, default=default.wd, help='weight decay')
  parser.add_argument('--mom', type=float, default=default.mom, help='momentum')
  parser.add_argument('--frequent', type=int, default=default.frequent, help='')
  parser.add_argument('--per-batch-size', type=int, default=default.per_batch_size, help='batch size in each context')
  parser.add_argument('--kvstore', type=str, default=default.kvstore, help='kvstore setting')
  args = parser.parse_args()
  return args


def get_symbol(args):
  embedding = eval(config.net_name).get_symbol()
  all_label = mx.symbol.Variable('softmax_label')
  gt_label = all_label
  is_softmax = True
  if config.loss_name=='softmax': #softmax
    _weight = mx.symbol.Variable("fc7_weight", shape=(config.num_classes, config.emb_size), 
        lr_mult=config.fc7_lr_mult, wd_mult=config.fc7_wd_mult, init=mx.init.Normal(0.01))
    if config.fc7_no_bias:
      fc7 = mx.sym.FullyConnected(data=embedding, weight = _weight, no_bias = True, num_hidden=config.num_classes, name='fc7')
    else:
      _bias = mx.symbol.Variable('fc7_bias', lr_mult=2.0, wd_mult=0.0)
      fc7 = mx.sym.FullyConnected(data=embedding, weight = _weight, bias = _bias, num_hidden=config.num_classes, name='fc7')
  elif config.loss_name=='margin_softmax':
    _weight = mx.symbol.Variable("fc7_weight", shape=(config.num_classes, config.emb_size), 
        lr_mult=config.fc7_lr_mult, wd_mult=config.fc7_wd_mult, init=mx.init.Normal(0.01))
    s = config.loss_s
    _weight = mx.symbol.L2Normalization(_weight, mode='instance')
    nembedding = mx.symbol.L2Normalization(embedding, mode='instance', name='fc1n')*s
    fc7 = mx.sym.FullyConnected(data=nembedding, weight = _weight, no_bias = True, num_hidden=config.num_classes, name='fc7')
    if config.loss_m1!=1.0 or config.loss_m2!=0.0 or config.loss_m3!=0.0:
      if config.loss_m1==1.0 and config.loss_m2==0.0:
        s_m = s*config.loss_m3
        gt_one_hot = mx.sym.one_hot(gt_label, depth = config.num_classes, on_value = s_m, off_value = 0.0)
        fc7 = fc7-gt_one_hot
      else:
        zy = mx.sym.pick(fc7, gt_label, axis=1)
        cos_t = zy/s
        t = mx.sym.arccos(cos_t)
        if config.loss_m1!=1.0:
          t = t*config.loss_m1
        if config.loss_m2>0.0:
          t = t+config.loss_m2
        body = mx.sym.cos(t)
        if config.loss_m3>0.0:
          body = body - config.loss_m3
        new_zy = body*s
        diff = new_zy - zy
        diff = mx.sym.expand_dims(diff, 1)
        gt_one_hot = mx.sym.one_hot(gt_label, depth = config.num_classes, on_value = 1.0, off_value = 0.0)
        body = mx.sym.broadcast_mul(gt_one_hot, diff)
        fc7 = fc7+body
  elif config.loss_name.find('triplet')>=0:
    is_softmax = False
    nembedding = mx.symbol.L2Normalization(embedding, mode='instance', name='fc1n')
    anchor = mx.symbol.slice_axis(nembedding, axis=0, begin=0, end=args.per_batch_size//3)
    positive = mx.symbol.slice_axis(nembedding, axis=0, begin=args.per_batch_size//3, end=2*args.per_batch_size//3)
    negative = mx.symbol.slice_axis(nembedding, axis=0, begin=2*args.per_batch_size//3, end=args.per_batch_size)
    if config.loss_name=='triplet':
      ap = anchor - positive
      an = anchor - negative
      ap = ap*ap
      an = an*an
      ap = mx.symbol.sum(ap, axis=1, keepdims=1) #(T,1)
      an = mx.symbol.sum(an, axis=1, keepdims=1) #(T,1)
      triplet_loss = mx.symbol.Activation(data = (ap-an+config.triplet_alpha), act_type='relu')
      triplet_loss = mx.symbol.mean(triplet_loss)
    else:
      ap = anchor*positive
      an = anchor*negative
      ap = mx.symbol.sum(ap, axis=1, keepdims=1) #(T,1)
      an = mx.symbol.sum(an, axis=1, keepdims=1) #(T,1)
      ap = mx.sym.arccos(ap)
      an = mx.sym.arccos(an)
      triplet_loss = mx.symbol.Activation(data = (ap-an+config.triplet_alpha), act_type='relu')
      triplet_loss = mx.symbol.mean(triplet_loss)
    triplet_loss = mx.symbol.MakeLoss(triplet_loss)
  out_list = [mx.symbol.BlockGrad(embedding)]
  if is_softmax:
    softmax = mx.symbol.SoftmaxOutput(data=fc7, label = gt_label, name='softmax', normalization='valid')
    out_list.append(softmax)
    if config.ce_loss:
      #ce_loss = mx.symbol.softmax_cross_entropy(data=fc7, label = gt_label, name='ce_loss')/args.per_batch_size
      body = mx.symbol.SoftmaxActivation(data=fc7)
      body = mx.symbol.log(body)
      _label = mx.sym.one_hot(gt_label, depth = config.num_classes, on_value = -1.0, off_value = 0.0)
      body = body*_label
      ce_loss = mx.symbol.sum(body)/args.per_batch_size
      out_list.append(mx.symbol.BlockGrad(ce_loss))
  else:
    out_list.append(mx.sym.BlockGrad(gt_label))
    out_list.append(triplet_loss)
  out = mx.symbol.Group(out_list)
  return out

def train_net(args):
    ctx = []
    cvd = os.environ['CUDA_VISIBLE_DEVICES'].strip()
    if len(cvd)>0:
      for i in range(len(cvd.split(','))):
        ctx.append(mx.gpu(i))
    if len(ctx)==0:
      ctx = [mx.cpu()]
      print('use cpu')
    else:
      print('gpu num:', len(ctx))
    prefix = os.path.join(args.models_root, '%s-%s-%s'%(args.network, args.loss, args.dataset), 'model')
    prefix_dir = os.path.dirname(prefix)
    print('prefix', prefix)
    if not os.path.exists(prefix_dir):
      os.makedirs(prefix_dir)
    args.ctx_num = len(ctx)
    args.batch_size = args.per_batch_size*args.ctx_num
    args.rescale_threshold = 0
    args.image_channel = config.image_shape[2]
    config.batch_size = args.batch_size
    config.per_batch_size = args.per_batch_size

    data_dir = config.dataset_path
    path_imgrec = None
    path_imglist = None
    image_size = config.image_shape[0:2]
    assert len(image_size)==2
    assert image_size[0]==image_size[1]
    print('image_size', image_size)
    print('num_classes', config.num_classes)
    path_imgrec = os.path.join(data_dir, "train.rec")

    print('Called with argument:', args, config)
    data_shape = (args.image_channel,image_size[0],image_size[1])
    mean = None

    begin_epoch = 0
    if len(args.pretrained)==0:
      arg_params = None
      aux_params = None
      sym = get_symbol(args)
      if config.net_name=='spherenet':
        data_shape_dict = {'data' : (args.per_batch_size,)+data_shape}
        spherenet.init_weights(sym, data_shape_dict, args.num_layers)
    else:
      print('loading', args.pretrained, args.pretrained_epoch)
      _, arg_params, aux_params = mx.model.load_checkpoint(args.pretrained, args.pretrained_epoch)
      sym = get_symbol(args)

    if config.count_flops:
      all_layers = sym.get_internals()
      _sym = all_layers['fc1_output']
      FLOPs = flops_counter.count_flops(_sym, data=(1,3,image_size[0],image_size[1]))
      _str = flops_counter.flops_str(FLOPs)
      print('Network FLOPs: %s'%_str)

    #label_name = 'softmax_label'
    #label_shape = (args.batch_size,)
    model = mx.mod.Module(
        context       = ctx,
        symbol        = sym,
    )
    val_dataiter = None

    if config.loss_name.find('triplet')>=0:
      from triplet_image_iter import FaceImageIter
      triplet_params = [config.triplet_bag_size, config.triplet_alpha, config.triplet_max_ap]
      train_dataiter = FaceImageIter(
          batch_size           = args.batch_size,
          data_shape           = data_shape,
          path_imgrec          = path_imgrec,
          shuffle              = True,
          rand_mirror          = config.data_rand_mirror,
          mean                 = mean,
          cutoff               = config.data_cutoff,
          ctx_num              = args.ctx_num,
          images_per_identity  = config.images_per_identity,
          triplet_params       = triplet_params,
          mx_model             = model,
      )
      _metric = LossValueMetric()
      eval_metrics = [mx.metric.create(_metric)]
    else:
      from image_iter import FaceImageIter
      train_dataiter = FaceImageIter(
          batch_size           = args.batch_size,
          data_shape           = data_shape,
          path_imgrec          = path_imgrec,
          shuffle              = True,
          rand_mirror          = config.data_rand_mirror,
          mean                 = mean,
          cutoff               = config.data_cutoff,
          color_jittering      = config.data_color,
          images_filter        = config.data_images_filter,
      )
      metric1 = AccMetric()
      eval_metrics = [mx.metric.create(metric1)]
      if config.ce_loss:
        metric2 = LossValueMetric()
        eval_metrics.append( mx.metric.create(metric2) )

    if config.net_name=='fresnet' or config.net_name=='fmobilefacenet':
      initializer = mx.init.Xavier(rnd_type='gaussian', factor_type="out", magnitude=2) #resnet style
    else:
      initializer = mx.init.Xavier(rnd_type='uniform', factor_type="in", magnitude=2)
    #initializer = mx.init.Xavier(rnd_type='gaussian', factor_type="out", magnitude=2) #resnet style
    _rescale = 1.0/args.ctx_num
    opt = optimizer.SGD(learning_rate=args.lr, momentum=args.mom, wd=args.wd, rescale_grad=_rescale)
    _cb = mx.callback.Speedometer(args.batch_size, args.frequent)

    ver_list = []
    ver_name_list = []
    for name in config.val_targets:
      path = os.path.join(data_dir,name+".bin")
      if os.path.exists(path):
        try:
          data_set = verification.load_bin(path, image_size)
        except:
          print('loading bins failed')
        ver_list.append(data_set)
        ver_name_list.append(name)
        print('ver', name)



    def ver_test(nbatch):
      results = []
      for i in range(len(ver_list)):
        acc1, std1, acc2, std2, xnorm, embeddings_list = verification.test(ver_list[i], model, args.batch_size, 10, None, None)
        print('[%s][%d]XNorm: %f' % (ver_name_list[i], nbatch, xnorm))
        #print('[%s][%d]Accuracy: %1.5f+-%1.5f' % (ver_name_list[i], nbatch, acc1, std1))
        print('[%s][%d]Accuracy-Flip: %1.5f+-%1.5f' % (ver_name_list[i], nbatch, acc2, std2))
        results.append(acc2)
      return results



    highest_acc = [0.0, 0.0]  #lfw and target
    #for i in range(len(ver_list)):
    #  highest_acc.append(0.0)
    global_step = [0]
    save_step = [0]
    lr_steps = [int(x) for x in args.lr_steps.split(',')]
    print('lr_steps', lr_steps)
    def _batch_callback(param):
      #global global_step
      global_step[0]+=1
      mbatch = global_step[0]
      for step in lr_steps:
        if mbatch==step:
          opt.lr *= 0.1
          print('lr change to', opt.lr)
          break

      _cb(param)
      if mbatch%1000==0:
        print('lr-batch-epoch:',opt.lr,param.nbatch,param.epoch)

      if mbatch>=0 and mbatch%args.verbose==0:
        acc_list = ver_test(mbatch)
        save_step[0]+=1
        msave = save_step[0]
        do_save = False
        is_highest = False
        if len(acc_list)>0:
          #lfw_score = acc_list[0]
          #if lfw_score>highest_acc[0]:
          #  highest_acc[0] = lfw_score
          #  if lfw_score>=0.998:
          #    do_save = True
          score = sum(acc_list)
          if acc_list[-1]>=highest_acc[-1]:
            if acc_list[-1]>highest_acc[-1]:
              is_highest = True
            else:
              if score>=highest_acc[0]:
                is_highest = True
                highest_acc[0] = score
            highest_acc[-1] = acc_list[-1]
            #if lfw_score>=0.99:
            #  do_save = True
        if is_highest:
          do_save = True
        if args.ckpt==0:
          do_save = False
        elif args.ckpt==2:
          do_save = True
        elif args.ckpt==3:
          msave = 1

        if do_save:
          print('saving', msave)
          arg, aux = model.get_params()
          if config.ckpt_embedding:
            all_layers = model.symbol.get_internals()
            _sym = all_layers['fc1_output']
            _arg = {}
            for k in arg:
              if not k.startswith('fc7'):
                _arg[k] = arg[k]
            mx.model.save_checkpoint(prefix, msave, _sym, _arg, aux)
          else:
            mx.model.save_checkpoint(prefix, msave, model.symbol, arg, aux)
        print('[%d]Accuracy-Highest: %1.5f'%(mbatch, highest_acc[-1]))
      if config.max_steps>0 and mbatch>config.max_steps:
        sys.exit(0)

    epoch_cb = None
    train_dataiter = mx.io.PrefetchingIter(train_dataiter)

    model.fit(train_dataiter,
        begin_epoch        = begin_epoch,
        num_epoch          = 999999,
        eval_data          = val_dataiter,
        eval_metric        = eval_metrics,
        kvstore            = args.kvstore,
        optimizer          = opt,
        #optimizer_params   = optimizer_params,
        initializer        = initializer,
        arg_params         = arg_params,
        aux_params         = aux_params,
        allow_missing      = True,
        batch_end_callback = _batch_callback,
        epoch_end_callback = epoch_cb )

def main():
    global args
    args = parse_args()
    train_net(args)

if __name__ == '__main__':
    main()
